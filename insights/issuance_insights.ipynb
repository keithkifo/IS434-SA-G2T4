# %%
import pandas as pd
import numpy as np
import networkx as nx

G = nx.read_gml('./graph.gml')

# %%
analytics_cluster = list( G.neighbors("Data Analytics Using Power BI") )

neighbours_dict = {}
for n in analytics_cluster:
    edge = G.get_edge_data("Data Analytics Using Power BI", n)
    neighbours_dict[n] = edge['weight']

# Sort according to the edge weight
analytics_sorted = sorted(neighbours_dict.items(), key=lambda pair: pair[1], reverse=True)

# %%
analytics_sorted
# Out:
# [('Data Analytics @ Work', 58),
#  ('Data Analytics Using Advanced Power BI', 43),
#  ('Tableau: Unlocking Insights with Analytics', 25),
#  ('DATA ANALYSIS FUNDAMENTALS USING MICROSOFT EXCEL (IBF)', 16),
#  ('Data Analytics for Managers', 10),
#  ('Enhance Teaching Effectiveness with Learning Analytics and Data Visualisation (I) - Bootcamp for Educationists, Teachers and School Leaders',
#   10),
#  ('CERTIFIED SCRUM MASTER (CSM)', 8),
#  ('PROJECT MANAGEMENT FOR ALL', 8),
#  ('ICAGILE - AGILE TEAM FACILITATION', 8),
#  ('ACCOUNTANCY', 8),
#  ('ICAGILE - AGILE COACHING', 7),
#  ('BUSINESS ANALYTICS WITH QLIK SENSE', 7),
#  ('Professional Certificate in\\nMachine Learning', 7),
#  ('Data Driven Design: Harnessing the Power of Predictive Analytics', 7),
#  ('Data Analytics Using Power BI', 7),
#  ('MACHINE LEARNING AND ADVANCED ANALYTICS USING PYTHON', 6),
#  ('Lean Six Sigma Yellow Belt', 6),
#  ('BUSINESS', 6),
#  ('BUILDING AN AGILE BUSINESS STRATEGY', 5),
#  ('HR Analytics Certificate - Using Analytics to Improve People Decisions (Foundation Level)',
#   5),
#  ('Practical Financial Modelling & Valuation', 5),
#  ('BLOCKCHAIN FOR CORPORATE COMPLIANCE', 5),
#  ('Practitioner Certificate in Personal Data Protection (Singapore)', 5),
#  ('Introduction to Accounting Data and Analytics', 5),
#  ('Data Management', 5),
#  ('Certificate\\nin Accounting Data\\nand Analytics', 5),
#  ('Data Modelling and Forecasting', 5),
#  ('Data Visualisation and Dashboarding', 5),
#  ('Coding with Python: Workshop for Accounting and Finance Professionals', 5),
#  ('Professional Certificate in Machine Learning (Python): Module 2 - Statistical Thinking and Exploratory Data Analysis',
#   5),
#  ('Professional Certificate in Machine Learning (Python): Module 4 - Advanced Concepts in Data Modelling',
#   5),
#  ('Professional Certificate in Machine Learning (Python): Module 3 - Basic Concepts in Data Modelling',
#   5),
#  ('Clearly Write: A Course on Effective Writing for Executives', 5),
#  ('BLOCKCHAIN FOR CROSS BORDER PAYMENT', 4),
#  ('Advanced Communication Strategies: Using Strategic Persuasion To Get What You Want',
#   4),
#  ('Corporate Credit Analysis', 4),
#  ('Advanced Certificate in Digital Business Module 2: Big Data Analytics and its Application in Smart Business',
#   4),
#  ('Professional Certificate in Machine Learning (Python): Module 1 - Introduction to Python Programming',
#   4),
#  ('Professional Certificate in Machine Learning (Python): Module 6 - Practical Concepts in Unsupervised Machine Learning',
#   4),
#  ('Professional Certificate in Machine Learning (Python): Module 5 - Practical Concepts in Supervised Machine Learning',
#   4),
#  ('Enhance Teaching Effectiveness with Learning Analytics and Data Visualisation (II) - Hands-on Training for Educationists and Teachers',
#   4),
#  ('Innovating Through Design Thinking: The Fundamentals', 4),
#  ('Business Analytics: Using Analytics to Solve Business Problems and Create Opportunities',
#   4),
#  ("Artificial Intelligence: A Layman's Approach", 4),
#  ('DATA ANALYSIS FUNDAMENTALS USING MICROSOFT EXCEL (IBF)-P210423ZWR', 4),
#  ('DATA ANALYTICS AND CREATING INTERACTIVE DASHBOARDS USING PYTHON', 3),
#  ('Certified HR Analytical Professional', 3),
#  ('Personal Leadership and Business Success Series: Management Efficacy', 3),
#  ('Leadership for Strategic Impact', 3),
#  ('Facilitating Innovation and Leading Change', 3),
#  ('Role of Effective Managers - Connecting the Dots!', 3),
#  ('Advanced Certification in Data Protection Operational Excellence Module 1: A Practical Approach to Data Protection for DPOs',
#   3),
#  ('Talent Management and Succession Planning', 3),
#  ('ICDL DATA ANALYTICS', 3),
#  ('Advancing Skillsets of Visual Analytics (using ggplot2 packages in R) (Synchronous e-learning)',
#   3),
#  ('Certified Data Analytics\\n(R) Specialist', 3),
#  ('Introduction to Data Visualisation (using R programming) (Synchronous e-learning)',
#   3),
#  ('Professional Certificate in Machine Learning (Python): Module 5 - Practical Concepts in Supervised Machine Learning (Synchronous e-learning)',
#   3),
#  ('ICAGILE - LEADING WITH AGILITY', 3),
#  ('ICAGILE - AGILE PRODUCT OWNERSHIP', 3),
#  ('Introduction to Data Analytics (using R Programming) (Synchronous e-learning)',
#   3),
#  ('Advanced Diploma in\\nPython Programming\\nand Machine Learning', 3),
#  ('Professional Certificate in Machine Learning (Python): Module 6 - Practical Concepts in Unsupervised Machine Learning (Synchronous e-learning)',
#   3),
#  ('ICAGILE - AGILITY IN HR-P210407ZXD', 3),
#  ('Business Processes:\\nService Excellence in Operations Strategy\\n(Synchronous e-learning)',
#   3),
#  ('Service Management - Strategies for Negotiation and Communication', 3),
#  ('Advanced Communication Strategies: Using Strategic Persuasion To Get What You Want (Synchronous E-learning)',
#   3),
#  ('ICAGILE - CERTIFIED AGILE PROFESSIONAL-P210225CFK', 3),
#  ('NICF - Fundamentals of Blockchain for Business Professionals (SF)', 3),
#  ('NICF - AGILE AND SCRUM FUNDAMENTALS (SF)', 3),
#  ('Agile for Successful Project Implementation', 3),
#  ('Optimising Your Analytics Function & Capability', 3),
#  ("Artificial Intelligence: A Layman's Approach (Synchronous e-learning)", 3),
#  ('FinTech: A Practical Introduction', 3),
#  ('Service Management - Strategies for Negotiation and Communication\\n(Synchronous e-learning)',
#   3),
#  ('Extracting Business Value Through Data Analytics', 3),
#  ('ENGINEERING (ELECTRICAL & ELECTRONIC ENGINEERING)', 3),
#  ('Graduate Certificate in Digital Finance Module 5:\\n Digital Forensics', 3),
#  ('HR Graduate Certification - Talent Management and Succession Planning', 3),
#  ('Lean Six Sigma Yellow Belt Certification', 3),
#  ('Advanced Certificate in Practical Business Law Module 2: Corporate Structure and Governance',
#   2),
#  ('Advanced Certificate in Practical Business Law Module 1: Understanding and Managing Common Business Contracts',
#   2),
#  ('Advanced Certificate in Transformation through Corporate Innovation Module 1: Corporate Innovation and New Markets',
#   2),
#  ('Advanced Diploma in Data Protection', 2),
#  ('Advanced Certificate in Data Protection Principles', 2),
#  ('Advanced Certificate in Transformation through Corporate Innovation Module 3: Strategy and Value Proposition in the Digital Age',
#   2),
#  ('Advanced Certificate in Transformation through Corporate Innovation Module 2: Leadership and the Future of Work in the Digital Economy',
#   2),
#  ('Advanced Certificate in Data Protection\\nOperational Excellence', 2),
#  ('Advanced Certificate in Sustainability & Sustainable Businesses: Module 5: Sustainable Finance, Impact Investing and Stewardship',
#   2),
#  ('Advanced Certificate in Sustainability & Sustainable Businesses: Module 4: Governance, Labour, HR Management and Business Integrity',
#   2),
#  ('Advanced Certificate in Sustainability & Sustainable Businesses: Module 3: Sustainable Supply Chain and the Circular Economy',
#   2),
#  ('Advanced Certificate in Sustainability & Sustainable Businesses: Module 2: Environmental Management for a Sustainable Economy',
#   2),
#  ('FUNDAMENTALS OF JAVA PROGRAMMING', 2),
#  ('Advanced Certificate in Digital Business Module 6: Tactics and Risk Management for Smart Business',
#   2),
#  ('Driving Performance Excellence', 2),
#  ('Talent Management for Business Leaders', 2),
#  ('Learning & Development', 2),
#  ('Lean Six Sigma Green Belt', 2),
#  ('AGILE INNOVATION POWERED BY ESSEC', 2),
#  ('SG SafeEvents Ambassador Programme', 2),
#  ('SKILLSFUTURE FOR DIGITAL WORKPLACE (LHUB)', 2),
#  ('Digital Marketing - Search Engine Marketing (Synchronous e-learning)', 2),
#  ('Advanced Data Protection Techniques: Data Protection by Design, DPIA & DPTM',
#   2),
#  ('Data Protection Principles in Asia Part 3 - Indonesia, Thailand, Rest of the World',
#   2),
#  ('Professional Certificate in\\nPython Programming', 2),
#  ('CERTIFIED SCRUM MASTER (CSM)-P200609QZH', 2),
#  ('ICAGILE - AGILE TEAM FACILITATION-P200520FHI', 2),
#  ('SMU Certificate in Artificial Intelligence Module 1: Building AI Capability with Basic Coding for Business',
#   2),
#  ('Statistical Inference for Managerial Insights (using R programming) (Synchronous e-learning)',
#   2),
#  ('Advanced Certificate in Data Protection Principles Module 4: Data Protection Principles in Asia Part 4 - Taiwan, China',
#   2),
#  ('ICAGILE - CERTIFIED AGILE PROFESSIONAL', 2),
#  ('DEVOPS LEADER (DOL)', 2),
#  ('Professional Certificate in Machine Learning (Python): Module 4 - Advanced Concepts in Data Modelling (Synchronous e-learning)',
#   2),
#  ('Web Scraping and Data Insights (using R programming) (Synchronous e-learning)',
#   2),
#  ('A First Look at Visual Analytics (using ggplot2 packages in R) (Synchronous e-learning)',
#   2),
#  ('Professional Certificate in Machine Learning (Python): Module 3 - Basic Concepts in Data Modelling (Synchronous e-learning)',
#   2),
#  ('CERTIFIED AGILE PROCESS OWNER (CAPO)', 2),
#  ('Certified Analytical Professional (Advanced Level)', 2),
#  ('Advanced Certificate in Digital Business Module 5: Smart Logistics and Supply Chain Management',
#   2),
#  ('PRIVATE HIRE CAR DRIVER VOCATIONAL LICENSE', 2),
#  ('Professional Certificate in Python Programming', 2),
#  ('Executive Certificate in Leadership & People Management - Talent Management for Business Leaders (Synchronous E-Learning)',
#   2),
#  ('Professional Certificate in Coaching', 2),
#  ('Module 4: Certified Coaching Skills (Synchronous E-Learning)', 2),
#  ('Module 3: Advanced Coaching Skills (Synchronous E-Learning)', 2),
#  ('Module 2: Intermediate Coaching Skills (Synchronous E-Learning)', 2),
#  ('Module 1: Foundations of Coaching (Synchronous E-Learning)', 2),
#  ('NICF - DATA APPRECIATION TO EXTRACT BUSINESS VALUE (SF)', 2),
#  ('WSQ-CERTIFIED TRAINING IN PEER-TO-PEER MENTAL WELL-BEING SUPPORT @ WORK',
#   2),
#  ('NICF - PROCESS AUTOMATION APPRECIATION (SF)', 2),
#  ('Advanced Certificate in Data Protection Principles Module 6: Data Protection Framework and Standards. ISO 29100, Nymity Accountability and APEC Privacy Framework',
#   2),
#  ('Advanced Certificate in Data Protection Principles Module 2: Data Protection Principles in Asia Part 2 - Philippines, Malaysia',
#   2),
#  ('Empathy at Work: Building an Empathic Organisational Culture (for Service Sector) (Synchronous E-Learning)',
#   2),
#  ('Graduate Certificate in Strategic Digital Transformation in Finance Module 3: Improving Financial Outcomes with Data Analytics - Going Beyond the Ledger',
#   2),
#  ('Advanced Certificate in Transformation through Corporate Innovation Module 5: Corporate Governance in the Digital Age',
#   2),
#  ('Advanced Certificate in Transformation through Corporate Innovation Module 6: Digital Customer Experience',
#   2),
#  ('Performance Evaluation & Management (Synchronous E-Learning)', 2),
#  ('Web Scraping and Data Insights (using R programming)', 2),
#  ('Introduction to Data Visualisation (using R programming)', 2),
#  ('Introduction to Data Analytics (using R Programming)', 2),
#  ('Advanced Diploma in\\nData Analytics and\\nMachine Learning', 2),
#  ('Advanced Certificate in Sustainability & Sustainable Businesses: Module 1: Sustainability, Strategic Community Investment & Impact Assessment',
#   2),
#  ('Module 7: Leading A Future-Focused People Strategy (Synchronous E-Learning)',
#   2),
#  ('Digital Strategy for Managers', 2),
#  ('Service Management - Strategies for Negotiation and Communication (Synchronous e-learning)',
#   2),
#  ('Employee Engagement & Change Management - Building an Agile Customer Centric Culture\\n(Synchronous e-learning)',
#   2),
#  ('Module 3: Designing Better Workplace For The Future of Work (Synchronous E-Learning)',
#   2),
#  ('Module 1: Diagnosing Workforce Gaps in Business Strategy (Synchronous E-Learning)',
#   2),
#  ('Module 2: Re-designing Work For The Future Workplace (Synchronous E-Learning)',
#   2),
#  ('SMU RPA Series: Core Module -\\nGetting Started with RPA', 2),
#  ('Becoming a Whole Leader (Synchronous E-Learning)', 2),
#  ('Digital Transformation - Building the Digital Brand Experience for Your Business\\n(Synchronous e-learning)',
#   2),
#  ('Industry 4.0 & Supply Chain Transformation: Developing a Digital Supply Chain Strategic Mindset',
#   2),
#  ('Data Analytics - Harnessing Data for Quality Service Delivery, Value Enhancement & Outcomes\\n(Synchronous e-learning)',
#   2),
#  ('Visual Analytics with Tableau for Accounting and Finance Professionals', 2),
#  ('The Future of Work Protecting Yourself Against Cyber Attacks (Synchronous E-Learning)',
#   2),
#  ('Professional Certificate in Python Programming Module 1: Basics of Python Programming (Synchronous e-learning)',
#   2),
#  ('ENGINEERING (MECHANICAL ENGINEERING)', 2),
#  ('ENGINEERING (AEROSPACE ENGINEERING)', 2),
#  ('(CEBFP) CYBERSECURITY ESSENTIALS FOR BUSINESS AND FINANCE PROFESSIONALS',
#   2),
#  ('Advanced Certificate in Crisis Management in the Digital Age Module 6: Cyber War Game',
#   1),
#  ('Advanced Certificate in Practical Business Law Module 4: Fundamentals of Data Protection',
#   1),
#  ('Advanced Certificate in Practical Business Law Module 3: Legal Aspects of Workforce Management',
#   1),
#  ('PDPA - A HR Perspective', 1),
#  ('Advanced Certificate in Crisis Management in the Digital Age Module 4: Drivers of Reputation',
#   1),
#  ('Advanced Certificate in Transformation through Corporate Innovation Module 4: Operationalising Agile Transformation',
#   1),
#  ('Advanced Certificate in Crisis Management in the Digital Age Module 3: Leadership in Crisis',
#   1),
#  ('Data Protection Trends & the Role of the DPO', 1),
#  ('NICF - CERTIFIED INFORMATION SYSTEMS AUDITOR (CISA) (SF) (SYNCHRONOUS E-LEARNING)',
#   1),
#  ('Data Protection Management Programme (DPMP)', 1),
#  ('Professional Certificate in\\nDigital Marketing', 1),
#  ('A Practical Approach to Data Protection for DPOs', 1),
#  ('Advanced Certificate in Sustainability & Sustainable Businesses: Module 6: Sustainability Reporting and Sustainable Project Implementation',
#   1),
#  ('Graduate Certificate in Digital Finance Module 3: AI and Robotic Process Automation',
#   1),
#  ('Graduate Certificate in Digital Finance Module 1: Data and Accounting Analytics',
#   1),
#  ('Graduate Certificate in Digital Finance Module 5: Digital Forensics', 1),
#  ('Implementing Effective Processes to Support Innovation (Synchronous e-learning)',
#   1),
#  ('The Financial Potential and Risks of New Business Ideas (Synchronous e-learning)',
#   1),
#  ('CYBER SECURITY PROTECTION CERTIFICATE (CSPC)', 1),
#  ('CERTIFIED AGILE SERVICE MANAGER (CASM)', 1),
#  ('BUSINESS MODEL CANVAS - 9 STEPS TO A SUCCESSFUL BUSINESS', 1),
#  ('Advanced Certificate in Digital Business', 1),
#  ('Becoming a Whole Leader', 1),
#  ('Middle Managers’ Role in Strategy Implementation - The Lynchpin of Success',
#   1),
#  ('Success Factors for Leading Digital Transformation', 1),
#  ('ICAGILE - AGILE COACHING-P200524FLB', 1),
#  ('CYBINT CYBER SECURITY PROTECTION (CSPC) PROGRAM', 1),
#  ('Managing International Trade Financing Risks', 1),
#  ('Strategic Thinking and Business Acumen', 1),
#  ('LEADING WITH AN EXPERIMENTAL MINDSET', 1),
#  ('Module 4: Workforce Planning for the Future of Work', 1),
#  ('Practical Financial Modelling and Valuation', 1),
#  ('A Case Approach to Modelling Corporate Acquisitions and Buyouts', 1),
#  ('BLOCKCHAIN FOR CAPITAL MARKETS', 1),
#  ('Macro Market Fundamental Analysis', 1),
#  ('SGUnited Skills Business and Digital Transformation Programme', 1),
#  ('SAFE MANAGEMENT MEASURES - PREPARING WORKPLACE FOR COVID-19', 1),
#  ('Foundations of Brand Storytelling', 1),
#  ('Graduate Certificate in Applied Innovation Module 4: Storytelling for Innovation and Building Winning Corporate Cultures',
#   1),
#  ('Graduate Certificate in\\nInnovation', 1),
#  ('Graduate Diploma in\\nCommunication Management\\nand Innovation', 1),
#  ('Digital Marketing - Social Media Marketing (Synchronous e-learning)', 1),
#  ('Graduate Certificate in\\nCommunication Management', 1),
#  ('Strategies for Persuasive Presentations (Synchronous e-learning)', 1),
#  ('Building A Winning Corporate Culture', 1),
#  ('Introduction to Opportunity Recognition and Ideation Management', 1),
#  ("Innovation Management Tool 'Design Thinking'", 1),
#  ('Business Model and Technology Innovation', 1),
#  ('Business Storytelling Studio (Synchronous e-learning)', 1),
#  ('Data Protection Principles in Asia Part 1- Singapore, Hong Kong, India', 1),
#  ('General Data Protection Regulation (GDPR) & Application on Asia', 1),
#  ('Professional Certificate in Machine Learning (Python): Module 1 - Introduction to Python Programming (Synchronous e-learning)',
#   1),
#  ('Professional Certificate in Machine Learning (Python): Module 2 - Statistical Thinking and Exploratory Data Analysis (Synchronous e-learning)',
#   1),
#  ('Professional Certificate in Python - Python Professional Bootcamp: Module 1: Introduction to Python 2 versus Python 3 (Synchronous e-learning)',
#   1),
#  ('Professional Certificate in Python - Python Professional Bootcamp: Module 2: Writing Python Statements (Synchronous e-learning)',
#   1),
#  ('Professional Certificate in Python - Python Professional Bootcamp: Module 3: Methods and Functions, Milestone Project 1 (Synchronous e-learning)',
#   1),
#  ('Professional Certificate in Python - Python Professional Bootcamp: Module 4: Object Oriented Programming, Modules and Packages (Synchronous e-learning)',
#   1),
#  ('Professional Certificate in Python - Python Professional Bootcamp: Module 5: Errors and Exceptions Handling, Milestone Project 2 (Synchronous e-learning)',
#   1),
#  ('Tableau: Unlocking Insights with Analytics II', 1),
#  ('Professional Certificate in Python - Python Professional Bootcamp: Module 6: Python Decorators, Python Generators, Final Capstone Python Project (Synchronous e-learning)',
#   1),
#  ('FUNDAMENTALS OF DEVOPS', 1),
#  ('Advanced Diploma in Data Analytics and\\nMachine Learning', 1),
#  ('Data Protection Framework and Standards. ISO 29100, Nymity Accountability and APEC Privacy Framework',
#   1),
#  ('Data Protection Principles in Asia Part 2 - Philippines, Malaysia', 1),
#  ('Advanced Data Analytics - Making Better Customer Decisions Using Analytics (Synchronous e-learning)',
#   1),
#  ('AGILE APPROACH IN PROJECT MANAGEMENT', 1),
#  ('Strategic IP Management for Businesses', 1),
#  ('Advanced Certificate in Digital Business Module 4: Smart Finance and the Digital Payment Ecosystem',
#   1),
#  ('Advanced Certificate in Digital Business Module 1: Leading with Data Driven Strategy',
#   1),
#  ('Advanced Certificate in Digital Business Module 3: Smart Retail and Marketing',
#   1),
#  ('MASTER OF SCIENCE (SYSTEMS & PROJECT MANAGEMENT)', 1),
#  ('MASTER OF SCIENCE (MECHANICAL ENGINEERING)', 1),
#  ('Ceramics', 1),
#  ('Innovation Culture Catalyst (ICC) and Mindset: The Secrets that Drive People and Innovation Programmes',
#   1),
#  ('Graduate Certificate in Digital Finance Module 6: Managing Expanding Cyber Risks',
#   1),
#  ('Graduate Certificate in Digital Finance II Module 1: Developing a Digital Finance Strategy',
#   1),
#  ('Finance Essentials for Business Success (Synchronous E-Learning)', 1),
#  ('Digital Marketing - Creating and Curating Video Content in Your Digital Strategy',
#   1),
#  ('Graduate Certificate in Applied Innovation', 1),
#  ('The Financial Potential and Risks of New Business Ideas', 1),
#  ('DIGITAL MARKETING - PERSUASIVE COPYWRITING IN YOUR DIGITAL STRATEGY', 1),
#  ('Graduate Diploma in\\nCommunication Management\\nand Applied Innovation',
#   1),
#  ('Jump Start to Trading the Financial Markets - Fundamentals of Financial Markets I (FX and Commodities)',
#   1),
#  ('Certificate in Logistics and Supply Chain Management Module 1: Fundamentals of Supply Chain Management',
#   1),
#  ('Advanced Certificate in Integrating Sustainability for a Future-Ready Business Module 1: Sustainability, Strategic Community Investment & Impact Assessment',
#   1),
#  ('Advanced Certificate in Integrating Sustainability for a Future-Ready Business Module 2: Environmental Management for a Sustainable Economy',
#   1),
#  ('Executive Certificate in Leadership & People Management - Driving Performance Excellence (Synchronous E-Learning)',
#   1),
#  ('Executive Certificate in Leadership & People Management - Becoming a Whole Leader (Synchronous E-Learning)',
#   1),
#  ('Executive Certificate in Leadership & People Management - Facilitating Innovation and Leading Change',
#   1),
#  ('Executive Certificate in Leadership & People Management - Role of Effective Managers - Connecting the Dots! (Synchronous E-Learning)',
#   1),
#  ('Executive Certificate in Leadership & People Management - Leadership for Strategic Impact',
#   1),
#  ('FULL STACK DEVELOPER - CAPSTONE PROJECT 1', 1),
#  ('FULL STACK DEVELOPER - CAPSTONE PROJECT 2', 1),
#  ('NICF - PROGRAMMING IN C# (SF)', 1),
#  ('AI Ethics Governance Framework for Organisations', 1),
#  ('DEVELOPING AND HOSTING SPA (REACTJS), WASM (BLAZOR) & WPAS', 1),
#  ('NICF - DEVELOPING ASP.NET CORE MVC WEB APPLICATIONS (SF)', 1),
#  ('XAMARIN WITH AZURE SERVICES', 1),
#  ('FULL STACK DEVELOPER - CAPSTONE PROJECT 4', 1),
#  ('FULL STACK DEVELOPER - CAPSTONE PROJECT 3', 1),
#  ('DEVELOPING SOLUTIONS FOR MICROSOFT AZURE', 1),
#  ('VMWARE VIRTUALIZATION AND CLOUD FUNDAMENTALS', 1),
#  ('Advanced Certificate in Procurement Essentials Module 4: Advanced Procurement Negotiation',
#   1),
#  ('Advanced Certificate in Procurement Essentials', 1),
#  ('Advanced Diploma in Strategic Procurement', 1),
#  ('Advanced Certificate in Strategic Sourcing Module 1: Category Management',
#   1),
#  ('Advanced Certificate in Procurement Essentials Module 3: Evaluation and Bid Analysis',
#   1),
#  ('Advanced Certificate in Procurement Essentials Module 2: Mastering Specification Writing with Design Thinking',
#   1),
#  ('Advanced Certificate in Procurement Essentials Module 1: Fundamentals of Procurement',
#   1),
#  ('Advanced Certificate in Strategic Sourcing', 1),
#  ('Advanced Certificate in Strategic Sourcing Module 4: Supplier Relationship Management and Performance Measurement',
#   1),
#  ('Advanced Certificate in Strategic Sourcing Module 3: Contract Management',
#   1),
#  ('Advanced Certificate in Strategic Sourcing Module 2: Sourcing Essentials and Procurement Risk Management',
#   1),
#  ('Design Thinking - Designing a Competitive Customer Experience', 1),
#  ('TAXI DRIVER VOCATIONAL LICENCE', 1),
#  ('Advanced Certification in Data Protection Operational Excellence Module 5: Data Protection Trends & the Role of the DPO',
#   1),
#  ('ICAGILE - LEADING WITH AGILITY-P210127TNZ', 1),
#  ('Information & Cyber Security for Managers - EXIN Certification', 1),
#  ('NICF - RPA DESIGN & DEVELOPMENT (SF) (SYNCHRONOUS E-LEARNING)', 1),
#  ('AMENDMENTS TO THE PERSONAL DATA PROTECTION ACT (PDPA) WEBINAR', 1),
#  ('Digital Marketing - Building a WordPress Site for Conversion', 1),
#  ('NICF - CERTIFIED INFORMATION SYSTEMS SECURITY PROFESSIONAL (CISSP) (SF)',
#   1),
#  ('Digital Marketing - Creating and Curating Display Content in Your Digital Strategy (Synchronous e-learning)',
#   1),
#  ('ARTS (PUBLIC POLICY & GLOBAL AFFAIRS)', 1),
#  ('Hedging & Management of Energy Price Risk', 1),
#  ('Advanced Certificate \\n in \\n Technical Education Pedagogy', 1),
#  ('OPERATE FORKLIFT COURSE (RE-FRESHER)', 1),
#  ('Advanced Technology Stack Series: Beyond Imagination in Extended Reality (VR/ AR/ MR)',
#   1),
#  ('SKILLSFUTURE FOR DIGITAL WORKPLACE (LHUB) (SYNCHRONOUS AND ASYNCHRONOUS E-LEARNING)',
#   1),
#  ('Jump Start to Trading the Financial Markets - Fundamentals of Financial Markets II (Equity and Fixed Income)',
#   1),
#  ('Rewards (Compensation & Benefits)', 1),
#  ('Advanced Certificate in Data Protection Principles Module 3: Data Protection Principles in Asia Part 3 - Indonesia, Thailand, Rest of the World',
#   1),
#  ('The Future of Work - Harnessing the Limitless Potential of AI and IOT', 1),
#  ('Module 5: Digital HR - The Key to Organisational Transformation', 1),
#  ('Advanced Certificate in Data Protection Principles Module 5: General Data Protection Regulation (GDPR) & Application on Asia (Synchronous e-learning)',
#   1),
#  ('Certificate in Nutrition and Wellness: Contemporary Food', 1),
#  ('Certificate in Nutrition and Wellness: Nutrition for Weight Management', 1),
#  ('Certificate in Nutrition and Wellness: Diet and Disease', 1),
#  ('Performance Evaluation & Management', 1),
#  ('Mergers and Acquisitions', 1),
#  ('Advanced Certificate in Transformation through Corporate Innovation', 1),
#  ('Strategic HR', 1),
#  ('NICF - DATA VISUALIZATION WITH QLIK SENSE (SF) (SYNCHRONOUS E-LEARNING)',
#   1),
#  ('Certificate in Nutrition and Wellness', 1),
#  ('Certificate in Nutrition and Wellness: Mindfulness for Health: The Breathworks approach',
#   1),
#  ('Personal Leadership and Business Success Series: Personal Effectiveness (Synchronous E-Learning)',
#   1),
#  ('Certificate in Nutrition and Wellness: Active Aging', 1),
#  ('Certificate in Nutrition and Wellness: Personal Grooming and Wellness', 1),
#  ('Talent Acquisition', 1),
#  ('Advanced Certificate in Data Protection Principles Module 1: Data Protection Principles in Asia Part 1 - Singapore, Hong Kong, India',
#   1),
#  ('NICF - PROJECT MANAGEMENT FUNDAMENTALS (SF) (SYNCHRONOUS E-LEARNING)', 1),
#  ('Advanced Cyber Risk Management', 1),
#  ('Certificate in Financial Trading - Introduction to Trading Using Technical Analysis (Synchronous e-Learning)',
#   1),
#  ('FUNDAMENTALS OF THE PERSONAL DATA PROTECTION ACT (2020) (SYNCHRONOUS E-LEARNING)',
#   1),
#  ('Certificate in Exercise Science: Fitness and Conditioning', 1),
#  ('Certificate in Exercise Science: Injury Prevention and Rehabilitation', 1),
#  ('Certificate in Event Management and Entertainment: Creative Concepts and New Technology Levers',
#   1),
#  ('Certificate in Nutrition and Wellness: Applied Nutrition', 1),
#  ('Certificate in Exercise Science: Applied Sports Psychology', 1),
#  ('NICF - DEVOPS FOUNDATION (SF)', 1),
#  ('Statistical Inference for Managerial Insights (using R programming)', 1),
#  ('A First Look at Visual Analytics (using ggplot2 packages in R)', 1),
#  ('Implementing an AI Bot', 1),
#  ('Valuation: A Corporate Perspective', 1),
#  ('SMU RPA Series: Core Module - Getting Started with RPA', 1),
#  ('Innovating Through Design Thinking: The Fundamentals (Synchronous e-learning)',
#   1),
#  ('Empathy At Work: Building an Empathic Organisational Culture (for Service Sector)',
#   1),
#  ('Talent Acquisition (Synchronous E-learning)', 1),
#  ('HR Graduate Certification', 1),
#  ('Rewards (Compensation & Benefits) (Synchronous E-Learning)', 1),
#  ('Module 5: Digital HR - The Key to Organisational Transformation (Synchronous E-Learning)',
#   1),
#  ('Advanced Certificate in Future Workforce Architecture Module 6: A Principle-based Approach To Employment Legislations and Guidelines (Synchronous E-Learning)',
#   1),
#  ('Human Capital Leadership: Leading a Digital-Ready Workforce for Customer Centricity\\n(Synchronous e-learning)',
#   1),
#  ('Strategic HR (Synchronous E-Learning)', 1),
#  ('Executive Certificate in Leadership & People Management', 1),
#  ('Contract and Intellectual Property Management (Synchronous e-learning)', 1),
#  ('KNOW YOUR CUSTOMERS THROUGH HUMAN - CENTERED APPROACH', 1),
#  ('NICF - DATA APPRECIATION FOR OPERATIONS (SF)', 1),
#  ('Driving Performance Excellence (Synchronous E-Learning)', 1),
#  ('FINE ARTS IN VISUAL COMMUNICATION', 1),
#  ('ENGINEERING (COMPUTER ENGINEERING)', 1),
#  ('NICF - Fortinet FortiGate Network Security Professional (NSE 4) (SF)', 1),
#  ('Design Thinking - Designing a Competitive Customer Experience\\n(Synchronous e-learning)',
#   1),
#  ('Module 6: A Principle-based Approach To Employment Legislations and Guidelines (Synchronous E-Learning)',
#   1),
#  ('Advanced Certificate in Future Workforce Architecture Module 5: Digital HR - The Key to Organisational Transformation',
#   1),
#  ('Advanced Certificate in Future Workforce Architecture', 1),
#  ('Innovating through Design Thinking: Refresher for Practitioners', 1),
#  ('Design Leadership & Innovation: Harnessing the Strategic Value of Design in the Digital Age',
#   1),
#  ('Facilitator Certificate in Design Thinking', 1),
#  ('Design Leadership & Design Thinking Facilitation - \\nA Train-the-Trainer Programme',
#   1),
#  ('Advanced Certificate in Strategic Sourcing Module 2: Digital Procurement - Past, Present and Future',
#   1),
#  ('NICF - RPA DEVELOPER FOUNDATION TRAINING (SF) (SYNCHRONOUS E-LEARNING)', 1),
#  ('Venture Capital Financing for Startups', 1),
#  ('SCIENCE (MARITIME STUDIES)', 1),
#  ('Machine Learning - Without Mathematics and Programming', 1),
#  ('General Management', 1),
#  ('MANAGE SECURITY RISK AND EMERGENCIES', 1),
#  ('Create and Deliver a Winning Pitch: Techniques for Business Presentations (for Service Sector)',
#   1),
#  ('Executive Certificate in Risk Management Leadership', 1),
#  ('Enterprise Risk Management Programme Module 3: Operationalise Risk Management to Achieve Strategic Objectives',
#   1),
#  ('Innovating Through Design Thinking: The Fundamentals \\n(Synchronous e-learning)',
#   1),
#  ('Enterprise Risk Management Programme Module 2: Risk Management Framework and Implementation',
#   1),
#  ('Enterprise Risk Management Programme Module 1: Risk and Opportunity in Business Model',
#   1),
#  ('Lean Six Sigma Black Belt Certification', 1),
#  ('ARTS (PSYCHOLOGY)', 1),
#  ('ICAGILE - AGILITY IN MARKETING', 1),
#  ('CERTIFIED SCRUM PRODUCT OWNER (CSPO)-P200827KBW', 1),
#  ('Advanced Data Analytics - Making Better Customer Decisions Using Analytics\\n(Synchronous e-learning)',
#   1),
#  ('Advanced Certificate in\\nMachine Learning\\nWith R Programming', 1),
#  ('Machine Learning - Text as Data: Text Mining Techniques using R (Synchronous e-learning)',
#   1),
#  ('Machine Learning - Clustering and Dimensionality Reduction: Introduction to Unsupervised Machine Learning Techniques using R (Synchronous e-learning)',
#   1),
#  ('Machine Learning - Regression and Classification: Introduction to Supervised Machine Learning Techniques using R (Synchronous e-learning)',
#   1),
#  ('Certificate in Accounting Data and Analytics', 1),
#  ('Blended Marketing Strategy in the Digital Age: How to have it All (Synchronous E-Learning)',
#   1),
#  ('Internet of Things: Technology & Applications', 1),
#  ('Blockchain: Embarking on the Journey', 1),
#  ('Advanced Certificate in RegTech Module 1: Regulatory Monitoring, Reporting and Compliance in the Finance Industry',
#   1),
#  ('Advanced Certificate in RegTech Module 6: RegTech Applicability Outside the Financial Services Industry',
#   1),
#  ('Advanced Certificate in RegTech Module 2: RegTech Use Cases from Different Perspectives: Finance Institutions vs Regulators vs FinTechs vs Consumers',
#   1),
#  ('Advanced Certificate in RegTech Module 5: RegTech Trends and Opportunities - From RegTech to TechReg',
#   1),
#  ('Advanced Certificate in RegTech Module 3: RegTech Innovation Focus I - Digitalisation, Data Analytics, Machine Learning and AI',
#   1),
#  ('Digital Outreach - Marketing to the Digital Consumer\\n(Synchronous e-learning)',
#   1),
#  ('Customer Loyalty: Gaining Insights from Consumer Psychology and Behavioural Science (Synchronous e-learning)',
#   1),
#  ('Professional Certificate in Python Programming Module 3: Advanced Functions and Data Structures in Python (Synchronous e-learning)',
#   1),
#  ('Project Finance Modelling', 1),
#  ('Doctor of Philosophy', 1),
#  ('Advanced Certification in Data Protection Operational Excellence Module 3: Advanced Data Protection Techniques: Data Protection by Design, DPIA & DPTM',
#   1),
#  ('Advanced Certificate in Practical Business Law Module 6: Protecting and Managing Intellectual Property',
#   1),
#  ('Advanced Certificate in Practical Business Law Module 5: Legal Aspects of Marketing, Advertising, and Consumer Protection',
#   1),
#  ('Advanced Certificate in Practical Business Law Module 7: Resolving Commercial Disputes',
#   1),
#  ('Advanced Certificate in Blockchain for Business Module 3: Blockchain Technology Developments and Industry Adoption (Synchronous E-learning)',
#   1),
#  ('Advanced Certificate in Blockchain for Business Module 5: Blockchain Governance, Compliance and Regulation (Synchronous E-learning)',
#   1),
#  ('Advanced Certificate in Blockchain for Business Module 2: Blockchain and Digital Transformation (Synchronous E-learning)',
#   1),
#  ('Advanced Certificate in Blockchain for Business Module 4: Blockchain Solutions Implementation (Synchronous E-learning)',
#   1),
#  ('Advanced Certificate in Data Protection Operational Excellence Module 1: A Practical Approach to Data Protection for DPOs.',
#   1),
#  ('Advanced Certificate in Practical Business Law', 1),
#  ('Advanced Certificate in Blockchain for Business', 1),
#  ('Advanced Certificate in Blockchain for Business Module 6: Blockchain Sustainability (Synchronous E-learning)',
#   1),
#  ('Advanced Certification in Data Protection Operational Excellence Module 4: Data Protection Management Programme (DPMP)',
#   1),
#  ('Advanced Certificate in Blockchain for Business Module 1: Blockchain Fundamentals',
#   1),
#  ('NICF - IT FUNDAMENTALS PART 1 (SF)', 1),
#  ('NICF - IT FUNDAMENTALS PART 2 (SF)', 1),
#  ('BLOCKCHAIN FOR CAPITAL MARKETS-P190414WWH', 1),
#  ('BLOCKCHAIN FOR CORPORATE COMPLIANCE-P190414NCC', 1),
#  ('ENGINEERING (COMPUTER SCIENCE)', 1),
#  ('Advanced Business Presentation (Synchronous e-Learning)', 1),
#  ('ENGINEERING (CHEMICAL & BIOMOLECULAR ENGINEERING)', 1),
#  ('SAP HANA INTRODUCTION (HA100)-P210423SQG', 1),
#  ('Advanced Certificate in Governance, Risk Management and Data Compliance Module 5: A Hands-on Approach to Governance, Risk and Compliance',
#   1),
#  ('Learning & Development (Synchronous E-Learning)', 1),
#  ('Private Banking Certification Level 1: Investment Advisory', 1),
#  ('Private Banking Certification Level 1: Ethical Conduct', 1),
#  ('Private Banking Certification Level 2: Investment Advisory - Behavioural Finance',
#   1),
#  ("Where's the Market Heading? Macroeconomics Views and Analysis", 1),
#  ('Private Banking: Private Equity and Venture Capital', 1),
#  ('Private Banking Certification Level 1: Client Relationship Management', 1),
#  ('Private Banking Certification Level 1: Digital Skills', 1),
#  ('Private Banking Certification Level 1: Wealth Planning', 1),
#  ('Options and Structured Product', 1),
#  ('Fixed Income Solutions', 1),
#  ('Equity, Mutual Funds, ETFs & REITs', 1),
#  ('Digital Strategy: Building Digital Capabilities to Transform Customer Experiences\\n(Synchronous e-learning)',
#   1),
#  ('MASTER OF SCIENCE (MARKETING & CONSUMER INSIGHT)', 1),
#  ('PDPA - An Operational Perspective', 1),
#  ('Graduate Certificate in Strategic Digital Transformation in Finance Module 1: Digital Strategy for Finance Managers',
#   1),
#  ('Graduate Certificate in Strategic Digital Transformation in Finance Module 4: Design Thinking for Finance Professionals - The Human-Centered Approach to Innovation',
#   1),
#  ('Cyber Security Risk Management for Finance Professionals', 1),
#  ('AGILE APPROACH IN PROJECT MANAGEMENT-P210216NTM', 1),
#  ('PROJECT MANAGEMENT FOR ALL-P200309QCS', 1),
#  ('OCCUPATIONAL FIRST AID COURSE', 1),
#  ('CPR(HANDS-ONLY)+AED PROVIDER', 1),
#  ('Bachelor of Business Administration', 1),
#  ('Applying Smart Tech in a Smart Way: The Right Approach to Digital Transformation (Synchronous e-learning)',
#   1),
#  ('FinTech: The Future of Money, Markets and Banking', 1),
#  ('Fundamentals of Entrepreneurship', 1),
#  ('Developing an Entrepreneurial Business Plan', 1),
#  ('Entrepreneurial Business Development', 1),
#  ('Entrepreneurial Marketing', 1),
#  ('SC101: Smart Cities Technologies, Regulations, and Future Trends (Synchronous E-learning)',
#   1),
#  ('Advanced Certificate in Data Protection Operational Excellence Module 5: Data Protection Trends & the Role of the DPO \\n(Synchronous E-learning)',
#   1),
#  ('Data Modelling and Forecasting (Synchronous E-learning)', 1),
#  ('Professional Certificate in Accounting and Finance', 1),
#  ('SCIENCE (BIOLOGICAL SCIENCES)', 1),
#  ('Graduate Certificate in Digital Finance Module 2:\\n Digital Assets & Blockchain Technology',
#   1),
#  ('SMU Executive Certificate in Transaction Banking  (IBF Level 1)', 1),
#  ('SMU Executive Certificate in EdTech for Educators Module 1: Understanding the Power of EdTech',
#   1),
#  ('SMU Executive Certificate in EdTech for Educators Module 2: Building Capacity for the Effective Use of EdTech',
#   1),
#  ('SMU Executive Certificate in EdTech for Educators', 1),
#  ('MASTER OF BUSINESS ADMINISTRATION', 1),
#  ('OFFICE 365 END USER TRAINING(SYNCHRONOUS E-LEARNING)', 1),
#  ('ENGINEERING (ENVIRONMENTAL ENGINEERING)', 1),
#  ('SCIENCE (APPLIED PHYSICS)', 1),
#  ('Certificate in Digital Video Design', 1),
#  ('Unlocking Maximum Performance - Business Creativity & Global Mindset (Synchronous E-Learning)',
#   1),
#  ('SCIENCE (MATHEMATICAL SCIENCES)', 1),
#  ('Bachelor of Business Administration (Accountancy)', 1),
#  ('FUNDAMENTALS OF PYTHON PROGRAMMING-P210804LBF', 1)]

# %%
count = 0
for i in nx.isolates(G):
    # print(i)
    count += 1

print(count)
# Out:
# 306

# %%
print(nx.density(G))
# Out:
# 0.01985887010394084

# %% [markdown]
# ### Degree Centrality

# %%
print("Nodes with Highest Degree Centrality")
print()

centrality = nx.degree_centrality(G)
top_degree_centrality = sorted(centrality.items(), key = lambda x: x[1], reverse=True)

degree_df = pd.DataFrame( data = {"certificate": [ c[0] for c in top_degree_centrality ], "degree_centrality": [ c[1] for c in top_degree_centrality] })
# Out:
# Nodes with Highest Degree Centrality

# %%
degree_df[degree_df["certificate"] == "Preparatory Course for Undergraduate Physics"]
# Out:
#                                        certificate  degree_centrality
# 3054  Preparatory Course for Undergraduate Physics                0.0

# %% [markdown]
# ### Betweenness Centrality

# %%
# High betweenness centralities suggest that these courses were important brokers=
print("Nodes with High Betweeness Centrality")
print()

betweenness = nx.betweenness_centrality(G, normalized=False)
top_betweenness = sorted(betweenness.items(), key = lambda x: x[1], reverse=True)

between_df = pd.DataFrame( data = {"certificate": [ c[0] for c in top_betweenness ], "betweenness": [ c[1] for c in top_betweenness] })
between_df
# Out:
# Nodes with High Betweeness Centrality
#                                             certificate    betweenness
# 0     DATA ANALYSIS FUNDAMENTALS USING MICROSOFT EXC...  245646.983764
# 1                            PROJECT MANAGEMENT FOR ALL  199078.896099
# 2                     ICAGILE - AGILE TEAM FACILITATION  185257.545378
# 3          CYBER SECURITY PROTECTION CERTIFICATE (CSPC)  141984.123965
# 4                   BLOCKCHAIN FOR CROSS BORDER PAYMENT  106575.302195
# ...                                                 ...            ...
# 3051                Housekeeping Operation (Outpatient)       0.000000
# 3052  Practical Business Finance for Engineering and...       0.000000
# 3053  Advanced Diploma in Logistics and Supply Chain...       0.000000
# 3054       Preparatory Course for Undergraduate Physics       0.000000
# 3055                                BCLS + AED Provider       0.000000
#
# [3056 rows x 2 columns]

# %%
between_df[between_df["betweenness"] == 0]
# Out:
#                                             certificate  betweenness
# 2352                    Nurturing Learners and Learning          0.0
# 2353  P-Series: Cybersecurity Practice Module 4: Too...          0.0
# 2354  Building Organisational Resilency through Busi...          0.0
# 2355  SGUnited Skills Programme in Cyber Security Sp...          0.0
# 2356  Advanced Diploma in Procurement Management & S...          0.0
# ...                                                 ...          ...
# 3051                Housekeeping Operation (Outpatient)          0.0
# 3052  Practical Business Finance for Engineering and...          0.0
# 3053  Advanced Diploma in Logistics and Supply Chain...          0.0
# 3054       Preparatory Course for Undergraduate Physics          0.0
# 3055                                BCLS + AED Provider          0.0
#
# [704 rows x 2 columns]

# %%
btwn_deg_df = pd.merge(degree_df, between_df, on="certificate")
btwn_deg_df[(btwn_deg_df["betweenness"] == 0) & (btwn_deg_df["degree_centrality"] != 0)]
# Out:
#                                             certificate  degree_centrality  \
# 1290  NICF - IDENTITY WITH WINDOWS SERVER (SF) (SYNC...           0.013093
# 1515  Where is the Market Heading? Macroeconomics Vi...           0.008838
# 1516    SMU-BOS Advanced Certificate in Private Banking           0.008838
# 1545  Advanced Certificate in Healthcare Management ...           0.008511
# 1562                SGUS APPLIED VR AND GAME SPECIALIST           0.008183
# ...                                                 ...                ...
# 2745        Diploma in Fashion Marketing and Management           0.000327
# 2746                  Neural Networks and Deep Learning           0.000327
# 2747     BUILDING CONSTRUCTION SUPEVISORS SAFETY COURSE           0.000327
# 2748                 Advanced Diploma in Cyber Security           0.000327
# 2749                    DIPLOMA IN INFO-COMM TECHNOLOGY           0.000327
#
#       betweenness
# 1290          0.0
# 1515          0.0
# 1516          0.0
# 1545          0.0
# 1562          0.0
# ...           ...
# 2745          0.0
# 2746          0.0
# 2747          0.0
# 2748          0.0
# 2749          0.0
#
# [398 rows x 3 columns]

# %% [markdown]
# ### Closeness Centrality

# %%
# High closeness suggest that, on average, they have short paths to many other nodes, which can be helpful for disseminating resources quickly
print("Nodes with High Closeness Centrality")
print()

closeness = nx.closeness_centrality(G)
top_closeness = sorted(closeness.items(), key = lambda x: x[1], reverse=True)

close_df = pd.DataFrame( data = {"course": [ c[0] for c in top_closeness ], "closeness": [ c[1] for c in top_closeness] })
# Out:
# Nodes with High Closeness Centrality

# %%
triangles = nx.triangles(G)
top_triangles = sorted(triangles.items(), key = lambda x: x[1], reverse=True)

triangle_df = pd.DataFrame( data = {"course": [ c[0] for c in top_triangles ], "triangle_count": [ c[1] for c in top_triangles] })

# %% [markdown]
# ### Clustering Coefficient

# %%
clustering = nx.clustering(G)
top_clusters = sorted(clustering.items(), key = lambda x: x[1], reverse=True)

cluster_df = pd.DataFrame( data = {"course": [ c[0] for c in top_clusters ], "cluster_coef": [ c[1] for c in top_clusters] })

# %%
cluster_df[ cluster_df.cluster_coef == 1.0 ]
# Out:
#                                                 course  cluster_coef
# 0                      Nurturing Learners and Learning           1.0
# 1    P-Series: Cybersecurity Practice Module 4: Too...           1.0
# 2    Building Organisational Resilency through Busi...           1.0
# 3    SGUnited Skills Programme in Cyber Security Sp...           1.0
# 4    Advanced Diploma in Procurement Management & S...           1.0
# ..                                                 ...           ...
# 226                             Basic Portrait Drawing           1.0
# 227                         Probability and Statistics           1.0
# 228  AI for Biomedical image, Signal Analysis and H...           1.0
# 229              International Construction Management           1.0
# 230                                      Digital Logic           1.0
#
# [231 rows x 2 columns]

# %%
cluster_df[ cluster_df.cluster_coef != 1.0 ]
# Out:
#                                                  course  cluster_coef
# 231   Data Analytics - Optimizing Marketing Campaign...      0.996829
# 232                               SGUS NETWORK ENGINEER      0.996377
# 233                                         CCNA PART-1      0.996377
# 234               NETWORK ENGINEER - CAPSTONE PROJECT 2      0.996377
# 235       NETWORK ENGINEER - SUMMATIVE CAPSTONE PROJECT      0.996377
# ...                                                 ...           ...
# 3051                Housekeeping Operation (Outpatient)      0.000000
# 3052  Practical Business Finance for Engineering and...      0.000000
# 3053  Advanced Diploma in Logistics and Supply Chain...      0.000000
# 3054       Preparatory Course for Undergraduate Physics      0.000000
# 3055                                BCLS + AED Provider      0.000000
#
# [2825 rows x 2 columns]

# %%
# shortest_paths = dict(nx.shortest_path_length(G))
# shortest_paths

# %%
from networkx.algorithms.community import greedy_modularity_communities

c = sorted(greedy_modularity_communities(G), key=len, reverse=True)

community = c[0]
G2 = G.subgraph(community)

community_dict = {}

for cert in list(G2.nodes):
    connections = len(list(G.neighbors(cert)))
    community_dict[cert] = connections

# Sort according to the edge weight
community_sorted = sorted(community_dict.items(),
                          key=lambda pair: pair[1], reverse=True)

# %%
community_sorted
# Out:
# [('DATA ANALYSIS FUNDAMENTALS USING MICROSOFT EXCEL (IBF)', 1212),
#  ('PROJECT MANAGEMENT FOR ALL', 1189),
#  ('ICAGILE - AGILE TEAM FACILITATION', 1160),
#  ('BLOCKCHAIN FOR CROSS BORDER PAYMENT', 1104),
#  ('CYBER SECURITY PROTECTION CERTIFICATE (CSPC)', 1055),
#  ('BLOCKCHAIN FOR CORPORATE COMPLIANCE', 1029),
#  ('ICAGILE - AGILE COACHING', 963),
#  ('AGILE INNOVATION POWERED BY ESSEC', 959),
#  ('BUSINESS ANALYTICS WITH QLIK SENSE', 904),
#  ('BUSINESS MODEL CANVAS - 9 STEPS TO A SUCCESSFUL BUSINESS', 833),
#  ('CERTIFIED SCRUM MASTER (CSM)', 819),
#  ('BUILDING AN AGILE BUSINESS STRATEGY', 818),
#  ('CYBINT CYBER SECURITY PROTECTION (CSPC) PROGRAM', 801),
#  ('LEADING WITH AN EXPERIMENTAL MINDSET', 775),
#  ('DEVELOPING AN EXPERIMENTAL MINDSET WITHIN TEAMS', 739),
#  ('KNOW YOUR CUSTOMERS THROUGH HUMAN - CENTERED APPROACH', 727),
#  ('CULTIVATING AN EXPERIMENTAL MINDSET', 715),
#  ('BLOCKCHAIN FOR CAPITAL MARKETS', 694),
#  ('HFI UX 1 - USABILITY ENGINEERING COURSE', 655),
#  ('MACHINE LEARNING AND ADVANCED ANALYTICS USING PYTHON', 606),
#  ('SKILLSFUTURE FOR DIGITAL WORKPLACE (LHUB)', 593),
#  ('ICAGILE - AGILITY IN MARKETING', 592),
#  ('CYBERSECURITY ACT FUNDAMENTALS', 543),
#  ('CERTIFIED AGILE SERVICE MANAGER (CASM)', 514),
#  ('DEVOPS LEADER (DOL)', 504),
#  ('CERTIFIED SCRUM MASTER (CSM)-P200609QZH', 489),
#  ('SKILLSFUTURE FOR DIGITAL WORKPLACE (LHUB) (SYNCHRONOUS AND ASYNCHRONOUS E-LEARNING)',
#   488),
#  ('DATA ANALYTICS AND CREATING INTERACTIVE DASHBOARDS USING PYTHON', 468),
#  ('NICF - AGILE AND SCRUM FUNDAMENTALS (SF) (SYNCHRONOUS E-LEARNING)', 467),
#  ('ICDL DATA ANALYTICS', 462),
#  ('ICAGILE - CERTIFIED AGILE PROFESSIONAL-P210225CFK', 457),
#  ('ENGINEERING (MECHANICAL ENGINEERING)', 441),
#  ('SAFE MANAGEMENT MEASURES - PREPARING WORKPLACE FOR COVID-19', 440),
#  ('NICF - PROJECT MANAGEMENT FUNDAMENTALS (SF) (SYNCHRONOUS E-LEARNING)', 425),
#  ('SETTING UP AND RUNNING A BUSINESS', 407),
#  ('THE MACHINE LEARNING PIPELINE ON AWS', 402),
#  ('AWS CLOUD PRACTITIONER ESSENTIALS-P200609GMR', 399),
#  ('CPR(HANDS-ONLY)+AED PROVIDER', 398),
#  ('SG SafeEvents Ambassador Programme', 392),
#  ('(CEBFP) CYBERSECURITY ESSENTIALS FOR BUSINESS AND FINANCE PROFESSIONALS',
#   391),
#  ('ICAGILE - AGILE PRODUCT OWNERSHIP', 390),
#  ('DIGITAL PLATFORMS MANAGEMENT', 389),
#  ('NICF - AGILE AND SCRUM FUNDAMENTALS (SF)', 385),
#  ('SkillsFuture For Digital Workplace (LHUB) (Synchronous and Asynchronous e-learning)',
#   379),
#  ('CERTIFIED AGILE PROCESS OWNER (CAPO)', 359),
#  ('NICF - DATA APPRECIATION TO EXTRACT BUSINESS VALUE (SF)', 359),
#  ('OCCUPATIONAL FIRST AID COURSE', 345),
#  ('NICF - PROJECT MANAGEMENT FUNDAMENTALS (SF)', 341),
#  ('ICAGILE - LEADING WITH AGILITY', 339),
#  ('(CEBFP) CYBERSECURITY ESSENTIALS FOR BUSINESS AND FINANCE PROFESSIONALS-P200817WPR',
#   308),
#  ('CONTRACT AND INTELLECTUAL PROPERTY MANAGEMENT', 297),
#  ('ICAGILE - AGILE TEAM FACILITATION-P200520FHI', 296),
#  ('ICAGILE - AGILE COACHING-P200524FLB', 290),
#  ('SETTING UP AND RUNNING A BUSINESS (SYNCHRONOUS E-LEARNING)', 289),
#  ('ENGINEERING (ELECTRICAL & ELECTRONIC ENGINEERING)', 285),
#  ('ICAGILE - AGILITY IN HR-P210407ZXD', 282),
#  ('SG SAFEEVENTS AMBASSADOR (SEA)', 279),
#  ('NICF - PROCESS AUTOMATION APPRECIATION (SF) (SYNCHRONOUS E-LEARNING)', 278),
#  ('SG SAFEEVENTS AMBASSADOR (SEA) (SYNCHRONOUS E-LEARNING)', 276),
#  ('SkillsFuture For Digital Workplace (LHUB)', 275),
#  ('ICAGILE - CERTIFIED AGILE PROFESSIONAL', 275),
#  ('AGILE APPROACH IN PROJECT MANAGEMENT', 273),
#  ('CUSTOMER FRIENDLY LANGUAGE', 273),
#  ('5 STRATEGIES TO WIN WITH PEOPLE', 264),
#  ('Contract and Intellectual Property Management (Synchronous e-learning)',
#   260),
#  ('NICF - PROCESS AUTOMATION APPRECIATION (SF)', 256),
#  ('STRATEGY DEVELOPMENT USING BMC', 255),
#  ('THE 360 DEGREE LEADER', 250),
#  ('FUNDAMENTALS OF THE PERSONAL DATA PROTECTION ACT (2020) (SYNCHRONOUS E-LEARNING)',
#   249),
#  ('ENHANCED DIGITAL MARKETING-P201208WTF', 246),
#  ('NICF - CYBERSECURITY AWARENESS PROGRAMME (SF)', 245),
#  ('DATA ANALYSIS FUNDAMENTALS USING MICROSOFT EXCEL (IBF)-P210423ZWR', 245),
#  ('BUILD RESILIENCE AND DEVELOP SKILLS TO LEAD CHANGE', 241),
#  ('CONTENT MARKETING STRATEGY', 241),
#  ('DIGITAL CITIZEN PLUS', 239),
#  ('FUNDAMENTALS OF JAVA PROGRAMMING', 235),
#  ('VMWARE VIRTUALIZATION AND CLOUD FUNDAMENTALS', 235),
#  ('SAFE MANAGEMENT OFFICERS COURSE FOR CONSTRUCTION', 235),
#  ('NICF - CYBERSECURITY AWARENESS PROGRAMME (SF) (SYNCHRONOUS E-LEARNING)',
#   235),
#  ('ENHANCED DIGITAL MARKETING', 234),
#  ('CERTIFIED SCRUM PRODUCT OWNER (CSPO)-P200827KBW', 226),
#  ('NICF - DATA APPRECIATION FOR OPERATIONS (SF)', 225),
#  ('SAFE MANAGEMENT OFFICER COURSE FOR CONSTRUCTION', 223),
#  ('NICF - DATA APPRECIATION FOR OPERATIONS (SF) (SYNCHRONOUS E-LEARNING)',
#   221),
#  ('NICF - ANALYZING AND VISUALIZING DATA WITH POWER BI (SF)', 220),
#  ('ICAGILE - AGILITY IN MARKETING-P200717ZFF', 213),
#  ('BE A SERVICE DESIGN THINKER POWERED BY ESSEC', 212),
#  ('MICROSOFT AZURE CLOUD FUNDAMENTALS-P200622GEO', 208),
#  ('TDVL REFRESHER (NON-ACTIVE DRIVER) COURSE', 208),
#  ('5 LEVELS OF LEADERSHIP', 204),
#  ('ICAGILE - LEADING WITH AGILITY-P210127TNZ', 202),
#  ('DIGITAL CITIZEN', 200),
#  ('PROJECT MANAGEMENT FOR ALL-P200309QCS', 200),
#  ('ICDL DATA ANALYTICS (SYNCHRONOUS E-LEARNING)', 199),
#  ('Setting up and Running a Business (Synchronous e-learning)', 198),
#  ('ICDL Data Analytics', 197),
#  ('ONLINE COMMUNICATION AND COLLABORATION TOOLS', 194),
#  ('LEAN SIX SIGMA YELLOW BELT', 192),
#  ('PREPARING TO BE AN EFFECTIVE CITIZEN DEFENDER', 190),
#  ('DIGITAL LEARNING BASIC WORKSHOP', 187),
#  ('PRIVATE HIRE CAR DRIVER VOCATIONAL LICENSE', 186),
#  ('BASIC TO INTERMEDIATE ADOBE PHOTOSHOP', 185),
#  ('NICF - DATA VISUALIZATION WITH QLIK SENSE (SF) (SYNCHRONOUS E-LEARNING)',
#   179),
#  ('SGUnited Skills Business and Digital Transformation Programme', 178),
#  ('Occupational First Aid Course', 178),
#  ('NICF - IT FUNDAMENTALS PART 1 (SF)', 178),
#  ('SCIENCE (MATHEMATICAL SCIENCES)', 177),
#  ('BASICS OF DATA SCIENCE', 177),
#  ('Industry 4.0 & Supply Chain Transformation: Developing a Digital Supply Chain Strategic Mindset',
#   174),
#  ('NICF - DATA APPRECIATION TO EXTRACT BUSINESS VALUE (SF) (SYNCHRONOUS E-LEARNING)',
#   173),
#  ('PREPARING TO BE AN EFFECTIVE CITIZEN DEFENDER (SYNCHRONOUS E-LEARNING)',
#   172),
#  ('INTRODUCTION TO INTERNET OF THINGS', 166),
#  ('MACHINE LEARNING AND ADVANCED ANALYTICS USING PYTHON-P200511TDG', 163),
#  ('NICF - ANALYZING AND VISUALIZING DATA WITH POWER BI (SF) (SYNCHRONOUS E-LEARNING)',
#   162),
#  ('FUNDAMENTALS OF PYTHON PROGRAMMING-P210804LBF', 161),
#  ('WSQ-CERTIFIED TRAINING IN PEER-TO-PEER MENTAL WELL-BEING SUPPORT @ WORK',
#   160),
#  ('HFI UX 1 - USABILITY ENGINEERING COURSE-P200603FUZ', 159),
#  ('APPLY EMPLOYMENT ACT IN HR PRACTICES AND HR PROCESSES', 157),
#  ('NICF - IT FUNDAMENTALS PART 2 (SF)', 157),
#  ('NICF - CERTIFIED INFORMATION SYSTEMS SECURITY PROFESSIONAL (CISSP) (SF)',
#   156),
#  ('NICF - CERTIFIED INFORMATION SYSTEMS AUDITOR (CISA) (SF) (SYNCHRONOUS E-LEARNING)',
#   156),
#  ('CYBER SECURITY PROTECTION CERTIFICATE (CSPC)-P210531GVA', 155),
#  ('DEVELOP A RISK MANAGEMENT IMPLEMENTATION PLAN', 155),
#  ('NICF - DEVOPS FOUNDATION (SF)', 153),
#  ('NICF - RPA DESIGN & DEVELOPMENT (SF)', 153),
#  ('DATA ANALYTICS AND CREATING INTERACTIVE DASHBOARDS USING PYTHON-P200504JEW',
#   152),
#  ('NICF - CERTIFIED INFORMATION SYSTEMS SECURITY PROFESSIONAL (CISSP) (SF) (SYNCHRONOUS E-LEARNING)',
#   150),
#  ('BUILD RESILIENCE AND DEVELOP SKILLS TO LEAD CHANGE (SYNCHRONOUS E-LEARNING)',
#   149),
#  ('PREPARING TO BE AN EFFECTIVE CITIZEN DEFENDER (Synchronous and Asynchronous e-learning)',
#   148),
#  ('FUNDAMENTALS OF DEVOPS-P200611RAT', 146),
#  ('TAXI DRIVER VOCATIONAL LICENCE', 146),
#  ('COMMUNICATION STUDIES', 145),
#  ('NICF - RPA DEVELOPER FOUNDATION TRAINING (SF). (SYNCHRONOUS E-LEARNING)',
#   144),
#  ('ARTIFICIAL INTELLIGENCE AND MACHINE LEARNING - PART 1-P201120GFZ', 144),
#  ('SUPERVISE CONSTRUCTION WORK FOR WSH', 143),
#  ('NICF - CYBERSECURITY AWARENESS PROGRAMME (SF).', 141),
#  ('SEARCH ENGINE OPTIMISATION (SEO)', 138),
#  ('NICF - RPA DEVELOPER FOUNDATION TRAINING (SF)', 138),
#  ('MANAGE WORK AT HEIGHT', 136),
#  ('ENGINEERING (MATERIALS ENGINEERING)', 135),
#  ('RPA IN FINANCIAL SERVICES-P200805AOS', 135),
#  ('INTRODUCTION TO THE INDUSTRY', 132),
#  ('ICAGILE - AGILE PRODUCT OWNERSHIP-P210203CJL', 132),
#  ('SOIL, WATER, AIR AND TEMPERATURE', 132),
#  ('URBAN FARMING AND THE SINGAPORE MARKET', 132),
#  ('ARTS (ECONOMICS)', 131),
#  ('ASSOCIATE DATA ANALYST - CAPSTONE PROJECT 1', 131),
#  ('LIGHT AND CROP PHYSIOLOGY', 131),
#  ('NUTRIENTS AND CROP HEALTH', 131),
#  ('PLANT BASICS', 131),
#  ('PRACTICE STATISTICS', 130),
#  ('NICF - RPA DEVELOPER FOUNDATION TRAINING (SF).', 130),
#  ('CALCULUS AND OPTIMIZATION', 130),
#  ('ASSOCIATE DATA ANALYST - CAPSTONE PROJECT 3', 130),
#  ('CODECADEMY: PYTHON 3 PROGRAMMING', 130),
#  ('PESTS AND PREVENTION', 130),
#  ('FUNDAMENTALS OF JAVA PROGRAMMING-P200616TIZ', 130),
#  ('DIGITAL MARKETING FUNDAMENTALS', 130),
#  ('ASSOCIATE DATA ANALYST - CAPSTONE PROJECT 2', 130),
#  ('CODECADEMY: ANALYZE DATA WITH SQL', 130),
#  ('LEARN PYTHON AND AUTOMATE REPETITIVE TASKS', 130),
#  ('MATRICES AND LINEAR ALGEBRA', 130),
#  ('UDEMY: STATISTICS FOR DATA SCIENCE AND BUSINESS ANALYSIS', 130),
#  ('SCIENCE (CHEMISTRY & BIOLOGICAL CHEMISTRY)', 129),
#  ('PUMPS AND FILTRATION', 129),
#  ('FUNDAMENTALS OF PERSONAL DATA PROTECTION ACT (PDPA) BRIDGING COURSE', 129),
#  ('TYPES OF FARMING SYSTEMS', 129),
#  ('DRIP IRRIGATION II', 129),
#  ('DRIP IRRIGATION I', 129),
#  ('DISEASES AND PREVENTION', 129),
#  ('SET UP FURNITURE AND LIGHTS', 129),
#  ('GREENHOUSE AND INDOOR FARM TECHNOLOGY', 129),
#  ('PUTTING IT ALL TOGETHER', 128),
#  ('ASSOCIATE DATA ANALYST - CAPSTONE PROJECT 4', 128),
#  ('CONTROLLERS AND FERTIGATION', 128),
#  ('PIPING AND JOINTS', 128),
#  ('NICF - RPA DESIGN & DEVELOPMENT (SF) (SYNCHRONOUS E-LEARNING)', 128),
#  ('CODECADEMY: BUILD A MACHINE LEARNING MODEL WITH PYTHON', 128),
#  ('BASIC TO INTERMEDIATE ADOBE ILLUSTRATOR CC (SF)', 127),
#  ('BUILD E-COMMERCE WEBSITE USING WORDPRESS CMS AND WOOCOMMERCE PLUGIN', 126),
#  ('PERSONAL SAFETY & HYGIENE', 126),
#  ('ENGINEERING (CHEMICAL & BIOMOLECULAR ENGINEERING)', 125),
#  ('SET UP IRRIGATION SYSTEM', 125),
#  ('SAFE MANAGEMENT OFFICERS COURSE FOR CONSTRUCTION (SYNCHRONOUS E-LEARNING)',
#   124),
#  ('BLOCKCHAIN FOR CAPITAL MARKETS-P190414WWH', 124),
#  ('ASSESS RISKS WITHIN A DEFINED FUNCTIONAL AREA, AND DEVELOP COUNTERMEASURES AND CONTINGENCY PLANS',
#   123),
#  ('CONTRACT AND INTELLECTUAL PROPERTY MANAGEMENT (Synchronous and Asynchronous e-learning)',
#   123),
#  ('ENGINEERING (COMPUTER SCIENCE)', 123),
#  ('INTRODUCTION TO CLOUD COMPUTING-P210524CNW', 122),
#  ('Project Management Practice in Financial Industry', 121),
#  ('DOCTOR OF PHILOSOPHY', 121),
#  ('WORKSHOP FOR CEO / TOP MANAGEMENT', 120),
#  ('VIRTUAL EVENTS 101: IT’S MUCH MORE THAN JUST ZOOM', 118),
#  ('CONTRACT AND INTELLECTUAL PROPERTY MANAGEMENT (SYNCHRONOUS E-LEARNING)',
#   117),
#  ('INTRODUCTION TO SOFTWARE DEVELOPMENT LIFECYCLE (SDLC) AND SOFTWARE TESTING',
#   116),
#  ('SET UP MINI GREENHOUSE', 116),
#  ('NICF - DATA VISUALIZATION WITH QLIK SENSE (SF)', 116),
#  ('FIRE SAFETY AWARENESS COURSE', 116),
#  ('DIGITAL MARKETING AND ENGAGEMENT', 115),
#  ('CERTIFIED AGILE SERVICE MANAGER (CASM)-P200527UDD', 115),
#  ('FUNDAMENTALS OF THE PERSONAL DATA PROTECTION ACT (SYNCHRONOUS E-LEARNING)',
#   115),
#  ('MICROSOFT FORMS AND MICROSOFT POWER AUTOMATE', 114),
#  ('SAFE MANAGEMENT MEASURES - PREPARING WORKPLACE FOR COVID-19 (Synchronous e-learning)',
#   113),
#  ('SAFE MANAGEMENT MEASURES AND PROFESSIONAL ENGAGEMENT WITH GUESTS (SYNCHRONOUS E-LEARNING)',
#   112),
#  ('SAP HANA INTRODUCTION (HA100)-P210423SQG', 111),
#  ('CHEMICAL SAFETY AWARENESS', 111),
#  ('CPR(Hands-Only)+AED Provider', 111),
#  ('FUNDAMENTALS OF THE PERSONAL DATA PROTECTION ACT', 111),
#  ('SCIENCE (BIOLOGICAL SCIENCES)', 110),
#  ('VMWARE VIRTUALIZATION AND CLOUD FUNDAMENTALS-P200618PHD', 107),
#  ('PRESENTATION SKILLS', 107),
#  ('The 5 Levels of Leadership', 107),
#  ('LIGHT AND IRRIGATION PROGRAMMING', 107),
#  ('QUALITY STANDARDS AND FOOD SAFETY', 106),
#  ('FIRE WARDEN COURSE', 106),
#  ('PACKING AND STORAGE', 106),
#  ('TRANSPLANTING METHODS', 106),
#  ('SEEDING SUBSTRATE AND GERMINATION', 106),
#  ('DIGITAL PLATFORMS MANAGEMENT-P200616RSC', 106),
#  ('HARVESTING AND POST HARVEST OPERATION', 106),
#  ('CULTIVATING AN EXPERIMENTAL MINDSET-P200727WCW', 105),
#  ('SFA REGULATIONS AND FUNDING', 105),
#  ('IMPROVING MENTAL WELLBEING AND SELF-CARE FOR A HAPPIER YOU (SYNCHRONOUS AND ASYNCHRONOUS)',
#   105),
#  ('COMMUNITY FARM', 104),
#  ('ICAGILE - AGILITY IN HR', 104),
#  ('COMMERCIAL FARM I - SEEDING AND NURSERY OPERATIONS', 104),
#  ('DAILY MONITORING AND MEASUREMENT', 104),
#  ('ENGINEERING (AEROSPACE ENGINEERING)', 102),
#  ('SET UP CONTROLLER AND PUMP', 101),
#  ('INTRODUCTION TO SOFTWARE-DEFINED DATA CENTER (SDDC)', 101),
#  ('GOOGLE ADWORDS: SEARCH, DISPLAY & VIDEO', 98),
#  ('SETTING UP AND RUNNING A BUSINESS (Synchronous and Asynchronous e-learning)',
#   98),
#  ('DIGITAL MARKETING AND E-COMMERCE SPECIALIST - CAPSTONE PROJECT 2', 98),
#  ('DEVOPS LEADER (DOL)-P200605VLF', 98),
#  ('INTRODUCTION TO UX/UI', 98),
#  ('UNDERSTANDING E-COMMERCE, INSIGHTS AND TRENDS', 98),
#  ('FACEBOOK AND INSTAGRAM MARKETING', 97),
#  ('SALES AND MARKETING STRATEGY', 97),
#  ('COMMERCIAL FARM II - GROW OUT AND POST HARVEST OPERATIONS', 97),
#  ('DIGITAL MARKETING AND E-COMMERCE SPECIALIST - CAPSTONE PROJECT 3', 97),
#  ('AGILE INNOVATION POWERED BY ESSEC-P200723YYZ', 96),
#  ('E-COMMERCE I', 96),
#  ('BRANDING AND POSITIONING', 96),
#  ('E-COMMERCE II', 96),
#  ('SUPPLY CHAIN AND INVENTORY MANAGEMENT', 96),
#  ('DIGITAL MARKETING AND E-COMMERCE SPECIALIST - CAPSTONE PROJECT 1', 96),
#  ('UNDERSTANDING CROSS BORDER TRADE, CUSTOMS AND TAXATION', 96),
#  ('DIGITAL MARKETING AND E-COMMERCE SPECIALIST - CAPSTONE PROJECT 5', 95),
#  ('NICF - FUNDAMENTALS OF BLOCKCHAIN FOR BUSINESS PROFESSIONALS (SF) (SYNCHRONOUS E-LEARNING)',
#   95),
#  ('DATA APPRECIATION TO EXTRACT BUSINESS VALUE', 95),
#  ('OPERATION ACCOUNTING I', 94),
#  ('VERTICAL FARM', 94),
#  ('OPERATION ACCOUNTING II', 94),
#  ('ASSOCIATE DATA ANALYST - SUMMATIVE CAPSTONE PROJECT', 94),
#  ('PRICING AND DISTRIBUTION CHANNELS', 94),
#  ('BUSINESS PLAN', 94),
#  ('GOOGLE ANALYTICS', 93),
#  ('OPERATIONALIZING PDPA FOR HR', 93),
#  ('DIGITAL MARKETING AND E-COMMERCE SPECIALIST - CAPSTONE PROJECT 4', 93),
#  ('APPLY FUNDAMENTALS OF LOGIC PRO X IN MUSIC PRODUCTION (SYNCHRONOUS E-LEARNING)',
#   92),
#  ('OCCUPATIONAL FIRST AID REFRESHER COURSE', 92),
#  ('WECHAT AND TIKTOK MARKETING', 92),
#  ('DIGITAL MARKETING AND E-COMMERCE SPECIALIST - SUMMATIVE CAPSTONE PROJECT',
#   91),
#  ('INTRODUCTION TO INTERNET OF THINGS-P201110BHX', 91),
#  ('ALIBABA GET PROGRAMME (PART-2)', 91),
#  ('SGUS DIGITAL MARKETING AND E-COMMERCE SPECIALIST', 91),
#  ('ALIBABA GET PROGRAMME (PART-1)', 91),
#  ('SAFE MANAGEMENT MEASURES - PREPARING WORKPLACE FOR COVID-19 (SYNCHRONOUS E-LEARNING)',
#   91),
#  ('DIGITAL MARKETING AND E-COMMERCE SPECIALIST - CAPSTONE PROJECT 6', 91),
#  ('PERFORM WORK AT HEIGHT', 91),
#  ('AGILE APPROACH IN PROJECT MANAGEMENT-P210216NTM', 90),
#  ('HOW TO BEGIN YOUR YOUTUBE CONTENT CREATOR JOURNEY', 90),
#  ('SGUS DIGITAL AGRITECH OPERATIONS MANAGER', 90),
#  ('BUSINESS ANALYTICS WITH QLIK SENSE-P210315RQT', 89),
#  ('ICAGILE - AGILITY IN ENTERPRISE-P211006ZMQ', 89),
#  ('COMPETENCY & BEHAVIOURAL-BASED INTERVIEW', 88),
#  ('FUNDAMENTALS OF MACHINE AND AUTOMATION SAFETY', 88),
#  ('NEGOTIATION IN STAKEHOLDERS MANAGEMENT', 87),
#  ('PERFORM ADVANCED EXCEL FUNCTIONS', 87),
#  ('SGUS ASSOCIATE DATA ANALYST', 87),
#  ('BUILDING DASHBOARD FOR PEOPLE INTELLIGENCE (POWER BI)', 86),
#  ('ENSURE INFO AND CYBER SECURITY AT WORKPLACE', 86),
#  ('ENVIRONMENTAL CONTROL COORDINATOR (ECC) COURSE', 86),
#  ('RIDE OVER CHANGES THROUGH GROWTH MINDSET', 86),
#  ('EFFECTIVE PROPOSAL WRITING', 86),
#  ('CUSTOMER REFERRAL PROGRAMS & INFLUENCER MARKETING', 85),
#  ('DATA ANALYTICS - OPTIMIZING MARKETING CAMPAIGNS (GOOGLE ANALYTICS + BUSINESS FACEBOOK)',
#   84),
#  ('DATA ANALYTICS', 84),
#  ('ENGINEERING (ENVIRONMENTAL ENGINEERING)', 84),
#  ('DATA ANALYTICS - INTRODUCTION', 83),
#  ('AMAZON SETUP AND MANAGEMENT PART-2: GLOBAL (1)', 83),
#  ('AMAZON SETUP AND MANAGEMENT PART-1: SINGAPORE', 83),
#  ('DATA ANALYTICS - BUSINESS INTELLIGENCE & DATA DASHBOARDS (VISUALISATION)',
#   83),
#  ('MEDIA PUBLISHING & MARKETPLACE', 82),
#  ('AUDIO EDITING', 82),
#  ('EMOTIONAL INTELLIGENCE FOR CREW MEMBERS', 82),
#  ('INTELLECTUAL PROPERTY MANAGEMENT', 82),
#  ('MULTI-LAYERED IMAGE EDITING', 82),
#  ('TOOLS & WORKFLOW SETUP', 82),
#  ('2D ANIMATION', 82),
#  ('IRL GAMIFICATION WITH OPEN BADGES', 82),
#  ('GAMIFICATION FOR LMSS WITH MOODLE BADGES', 82),
#  ('ONLINE GAMIFICATION WITH GAMIPRESS', 82),
#  ('Occupational First Aid Refresher Course', 81),
#  ('ENGINEERING (INFORMATION ENGINEERING & MEDIA)', 81),
#  ('AMAZON SETUP AND MANAGEMENT PART-3: GLOBAL (2)', 81),
#  ('PROJECT MANAGEMENT FOR VR & GAMIFICATION', 81),
#  ('ARTS (LINGUISTICS & MULTILINGUAL STUDIES)', 79),
#  ('ADOPTING A WELLNESS APPROACH AT THE WORKPLACE', 79),
#  ('BLOCKCHAIN FOR CROSS BORDER PAYMENT-P190414BQC', 79),
#  ('GOING LIVE! ON SOCIAL MEDIA', 79),
#  ('Fundamentals of Financial and Accounting for Technology Professionals', 79),
#  ('MICROSOFT EXCEL INTERMEDIATE', 79),
#  ('DATA SCIENCE FUNDAMENTALS - MACHINE LEARNING USING R', 78),
#  ('MASTER OF SCIENCE (TECHNOPRENEURSHIP & INNOVATION)', 78),
#  ('SGUS DIGITAL HR BUSINESS PARTNER', 77),
#  ('Digital Transformation Programme', 75),
#  ('OPERATE FORKLIFT COURSE (RE-FRESHER)', 73),
#  ('PEDAGOGY FOR PERFORMING ARTS INSTRUCTORS (Synchronous e-learning)', 73),
#  ('EFFECTIVE BUSINESS WRITING', 73),
#  ('MASTER OF SCIENCE (INFORMATION SYSTEMS)', 73),
#  ('HIGH-VALUE INNOVATION THROUGH FUSION: BEHIND-THE-SCENES STORIES AND CREATIVITY PROCESS-P201023BSS',
#   72),
#  ('UNDERSTANDING BASIC WORKPLACE HEALTH PRACTICES', 71),
#  ('COMPTIA NETWORK+', 71),
#  ('FOUNDATION OF AUTOMATED SYSTEM USING ROBOTICS - DESIGN AND DEPLOY', 71),
#  ('COMPTIA SECURITY+', 71),
#  ('KNOW YOUR CUSTOMERS THROUGH HUMAN - CENTERED APPROACH-P200811BSD', 71),
#  ('VECTOR GRAPHICS', 70),
#  ('NICF - IT Fundamentals Part 1 (SF)', 70),
#  ('EFFECTIVE TIME AND STRESS MANAGEMENT AT THE WORKPLACE', 70),
#  ('CERTIFIED USABILITY ANALYST (CUA)', 70),
#  ('INTEGRATED MANAGEMENT SYSTEM (ISO9001,14001,45001) INTERNAL AUDITOR TRAINING',
#   70),
#  ('PREPARING TO BE AN EFFECTIVE CITIZEN DEFENDER (Synchronous e-learning)',
#   69),
#  ('TAKE CENTRESTAGE AND COMMAND AN AUDIENCE', 69),
#  ('ASSESS CONFINED SPACE FOR SAFE ENTRY AND WORK', 68),
#  ('VIDEO EDITING', 68),
#  ('DIGITAL MARKETING AND E-COMMERCE SPECIALIST', 68),
#  ('NICF - DATA APPRECIATION FOR OPERATIONS (SF)(SYNCHRONOUS E-LEARNING)', 67),
#  ('SKETCH UP', 67),
#  ('CONDUCTING MARKET RESEARCH', 67),
#  ("FROM 'HARD' SELL TO 'HEART' SELL", 66),
#  ('SALES 101', 66),
#  ('INTRODUCTION TO CRM & PIPELINE MANAGEMENT', 66),
#  ('BLENDER 3D', 66),
#  ('UNITY 3D', 66),
#  ('VR, GAME & GAMIFICATION PUBLISHING & DISTRIBUTION', 66),
#  ('ADVANCED 3D CONCEPTS', 66),
#  ('Growing Enterprises', 66),
#  ('MINI-GAME SYSTEM', 66),
#  ('APPLIED VR & GAME SPECIALIST - CAPSTONE PROJECT 1', 66),
#  ('STRATEGIC BUSINESS AND MARKETING PLAN', 66),
#  ('ENGINEERING (CIVIL)', 66),
#  ('BUILDING INTERACTIVE 3D', 66),
#  ('MICROSOFT EXCEL ADVANCED', 65),
#  ('NICF - JAVA SE: PROGRAMMING I (SF)', 65),
#  ('DATA ANALYTICS USING MICROSOFT EXCEL', 65),
#  ('WSH COMMITTEE MEMBERS TRAINING COURSE', 65),
#  ('SCIENCE (MARITIME STUDIES)', 65),
#  ('STRENGTHENING YOUR WELLNESS & RESILIENCE', 65),
#  ('RAPID PROTOTYPING FOR UI DESIGN USING ADOBE XD', 64),
#  ('PLAYSTRCTOR & 3DHIVE', 64),
#  ("KICKSTART ORGANISATION'S DP JOURNEY", 63),
#  ('CERTIFIED DIGITAL PERSUASION ANALYST (CDPA)', 63),
#  ('NICF - APPLE MACOS SUPPORT ESSENTIALS (SF)', 63),
#  ('ICT IN DATA PROTECTION', 63),
#  ('SMU Executive Certificate in Transaction Banking  (IBF Level 1)', 63),
#  ('ASSOCIATE UI/UX DESIGNER - CAPSTONE PROJECT 1', 63),
#  ('Blockchain for Capital Markets-P210920WUG', 63),
#  ('PRACTITIONER CERTIFICATE IN PDP 1-DAY BRIDGING COURSE', 63),
#  ('PRACTITIONER CERTIFICATE IN PERSONAL DATA PROTECTION (SINGAPORE)', 63),
#  ('DEVELOP AND IMPLEMENT ORGANISATIONAL-LEVEL DATA GOVERNANCE STRATEGY AND STRUCTURE',
#   63),
#  ('BASIC TO INTERMEDIATE ADOBE ILLUSTRATOR CC', 63),
#  ('DATA PROTECTION OFFICER - CAPSTONE PROJECT 1', 63),
#  ('BUSINESS MODEL CANVAS - 9 STEPS TO A SUCCESSFUL BUSINESS-P200811AUA', 63),
#  ('Growing Enterprise Module 4: Sales', 62),
#  ('Advanced Diploma in Growing and Transforming Enterprises', 62),
#  ('DESIGN A DATA BREACH MANAGEMENT PLAN', 62),
#  ('EFFECTIVE COMMUNICATION AND COLLABORATION IN THE DIGITAL AGE', 62),
#  ('DIGITAL CUSTOMER RELATIONS AMBASSADOR - CAPSTONE PROJECT 1', 62),
#  ('ASSOCIATE UI/UX DESIGNER - CAPSTONE PROJECT 3', 62),
#  ('ASSOCIATE DATA ANALYST - CAPSTONE PROJECT 1: CREATING INTERACTIVE DASHBOARDS AND DATA STORYTELLING WITH EXCEL',
#   62),
#  ('ASSOCIATE UI/UX DESIGNER - CAPSTONE PROJECT 2', 62),
#  ('ESSENTIAL VIDEO EDITING FROM SCRATCH USING PREMIERE PRO', 62),
#  ('FUNDAMENTALS OF WEB DESIGN AND DEVELOPMENT USING WORDPRESS', 62),
#  ('DATA PROTECTION OFFICER - CAPSTONE PROJECT 2', 61),
#  ('BASIC TO INTERMEDIATE ADOBE PHOTOSHOP CC', 61),
#  ('DATA PROTECTION OFFICER - CAPSTONE PROJECT 5', 61),
#  ('IMPLEMENT PERSONAL DATA SHARING POLICIES TO GENERATE BUSINESS VALUE FOR THE ORGANISATION',
#   61),
#  ('DATA PROTECTION OFFICER - CAPSTONE PROJECT 6', 61),
#  ('COMPLY WITH LOCAL DATA PROTECTION REQUIREMENTS WHILE DEVELOPING INNOVATIVE PRODUCTS AND SERVICES',
#   61),
#  ('JUMPSTART VIDEO EDITING WITH DAVINCI RESOLVE', 61),
#  ('Tissue - Material Interactions', 61),
#  ('PERFORM EXCEL FUNCTIONS', 61),
#  ('IDENTIFY UNETHICAL PRACTICES AND MITIGATE BUSINESS RISKS THROUGH ETHICAL CONTROLS',
#   61),
#  ('ELEMENTS OF DESIGN AND PHOTO EDITING WITH LIGHTROOM', 61),
#  ('DEVELOP AND ENHANCE COMPLIANCE PROCESSES IN BUSINESS OPERATIONS AND DATA PROTECTION REQUIREMENTS',
#   61),
#  ('ENGAGING, COMMUNICATING AND CLARIFYING RESPONSIBILITIES WITH STAKEHOLDERS',
#   61),
#  ('DATA PROTECTION OFFICER - CAPSTONE PROJECT 4', 61),
#  ('Organic Structural Materials', 61),
#  ('DATA PROTECTION OFFICER - CAPSTONE PROJECT 3', 60),
#  ('Organic Electronic Materials', 60),
#  ('DIGITAL WORKPLACE: BUSINESS PROCESS AND WORKFLOW AUTOMATION - DESIGN, DEPLOY AND MANAGE',
#   60),
#  ('Materials in Medicine', 59),
#  ('Counselling Older Persons', 59),
#  ('Growing Enterprise Module 2: People', 59),
#  ('Tissue Engineering & Drug Delivery', 59),
#  ('NICF - AGILE AND SCRUM FUNDAMENTALS (SF)(SYNCHRONOUS E-LEARNING)', 59),
#  ('SELF-DIRECTED LEARNING ON COMPLAINT MANAGEMENT', 58),
#  ('Organic Optical Materials', 58),
#  ('Growing Enterprise Module 3: Customer', 58),
#  ('Growing Enterprise Module 1: Strategy Development', 58),
#  ('RPA DEVELOPER FOUNDATION TRAINING', 58),
#  ('AWS CLOUD PRACTITIONER ESSENTIALS', 58),
#  ('ESSENTIAL MOTION GRAPHICS FOR ONLINE AND SOCIAL MEDIA MARKETING WITH AFTER EFFECTS FOR TOTAL BEGINNERS',
#   58),
#  ('SAFE MANAGEMENT OFFICER TRAINING', 58),
#  ('DIGITAL CUSTOMER RELATIONS AMBASSADOR - CAPSTONE PROJECT 2', 58),
#  ('MANAGE WORKPLACE SAFETY AND HEALTH IN CONSTRUCTION SITES', 57),
#  ('NICF - NETWORKING WITH WINDOWS SERVER (SF)', 57),
#  ('SYSTEMS ADMINISTRATOR - CAPSTONE PROJECT 1', 57),
#  ('Lean Six Sigma Yellow Belt Certification', 57),
#  ('SGUS DATA PROTECTION OFFICER (DPO)', 57),
#  ('ENTERPRISE RISK MANAGEMENT AND RISK SENSING-P210331CJP', 57),
#  ('SYSTEMS ADMINISTRATOR - CAPSTONE PROJECT 2', 57),
#  ('APPLY CONTINUOUS IMPROVEMENT THINKING IN THE WORKPLACE (SF) (SYNCHRONOUS E-LEARNING)',
#   57),
#  ('BUILDING AN AGILE BUSINESS STRATEGY-P210216JZM', 57),
#  ('ASSOCIATE UI/UX DESIGNER - CAPSTONE PROJECT 4', 57),
#  ('AI MODERN CITY - ROBOTIC CONTROL SERIES', 56),
#  ('ENTRY CERTIFICATE IN BUSINESS ANALYSIS (ECBA)', 56),
#  ('VMWARE VSPHERE: INSTALL, CONFIGURE, MANAGE (SF)', 56),
#  ('DATA APPRECIATION PROGRAMME', 56),
#  ('SYSTEMS ADMINISTRATOR - CAPSTONE PROJECT 4', 56),
#  ('MANAGE HAZARDOUS SUBSTANCES', 56),
#  ('SYSTEMS ADMINISTRATOR - CAPSTONE PROJECT 6', 56),
#  ('SYSTEMS ADMINISTRATOR - CAPSTONE PROJECT 5', 56),
#  ('SYSTEMS ADMINISTRATOR - CAPSTONE PROJECT 3', 56),
#  ('ROBOT DESIGN, BUILD & PROGRAM - FOUNDATIONAL SERIES 1', 55),
#  ('DESKTOP SUPPORT ENGINEER - CAPSTONE PROJECT 4', 55),
#  ('AI SMART HOME - ROBOTIC CONTROL SERIES', 55),
#  ('VMWARE HORIZON 7: INSTALL, CONFIGURE, MANAGE', 55),
#  ('DESKTOP SUPPORT ENGINEER - CAPSTONE PROJECT 2', 55),
#  ('MANAGING MODERN DESKTOPS', 55),
#  ('SELF-DIRECTED LEARNING ON SOCIAL MEDIA', 55),
#  ('DESKTOP SUPPORT ENGINEER - CAPSTONE PROJECT 5', 55),
#  ('CUSTOMER SERVICE & PROBLEM SOLVING SKILLS FOR HELP DESK PERSONNEL', 55),
#  ('DESKTOP SUPPORT ENGINEER - CAPSTONE PROJECT 3', 55),
#  ('INTRODUCTION TO SAFETY TECHNOLOGIES', 55),
#  ('COMMUNITY AND PARTNERSHIPS SPECIALIST - CAPSTONE PROJECT 2', 55),
#  ('DESKTOP SUPPORT ENGINEER - CAPSTONE PROJECT 1', 55),
#  ('GRIEVANCES HANDLING & CONSEQUENCE MANAGEMENT', 54),
#  ('SGUS SYSTEMS ADMINISTRATOR', 54),
#  ('DIGITAL HEALTH, SAFETY AND ENVIRONMENT (HSE) EXECUTIVE', 54),
#  ('NICF - DATA APPRECIATION TO EXTRACT BUSINESS VALUE', 54),
#  ('DESKTOP SUPPORT ENGINEER - CAPSTONE PROJECT 6', 54),
#  ('FOUNDATIONAL INDUSTRIAL DRONE PILOT COURSE', 54),
#  ('SGUS DIGITAL HEALTH, SAFETY AND ENVIRONMENT (HSE) EXECUTIVE', 53),
#  ('CONTRACT AND INTELLECTUAL PROPERTY MANAGEMENT (Synchronous e-learning)',
#   53),
#  ('CONTENT MARKETING', 53),
#  ('SYSTEMS ADMINISTRATOR - SUMMATIVE CAPSTONE PROJECT', 53),
#  ('THE FUNDAMENTALS OF EVENT PLANNING', 52),
#  ('CREATING EXEMPLARY VOLUNTEERING EXPERIENCE', 52),
#  ('ASSOCIATE DATA ANALYST', 52),
#  ('REINVENT YOUR CAREER: HOW TO SUCCEED IN THE GIG ECONOMY OF THE FUTURE', 52),
#  ('FULL UBTECH E-LEARNING AI/ROBOTIC SERIES (VALID FOR 1-YEAR)', 52),
#  ('ASSOCIATE UI/UX DESIGNER - SUMMATIVE CAPSTONE PROJECT', 51),
#  ('ROBOT DESIGN, BUILD & PROGRAM - FOUNDATIONAL SERIES 2', 51),
#  ('HR FOR NON-HR PROFESSIONALS', 51),
#  ('MAINTENANCE SAFETY COURSE LOCK-OUT PROCEDURES', 51),
#  ('BUSINESS PROCESS AND WORKFLOW AUTOMATION - DESIGN, DEPLOY AND MANAGE', 50),
#  ('NICF - Agile and Scrum Fundamentals (SF)', 50),
#  ('SKILLSFUTURE FOR DIGITAL WORKPLACE (LHUB) (Synchronous and Asynchronous e-learning)',
#   50),
#  ('General Management', 50),
#  ('FINE ARTS IN PRODUCT DESIGN', 50),
#  ('LEVERAGING DYNAMIC BUSINESS MODEL INNOVATION FOR COMPETITIVE ADVANTAGE',
#   50),
#  ('ROBOT DESIGN, BUILD & PROGRAM - ADVANCE SERIES', 50),
#  ('APPLY WORKPLACE SAFETY AND HEALTH IN PROCESS PLANT', 50),
#  ('BLOCKCHAIN FOR CORPORATE COMPLIANCE-P190414NCC', 49),
#  ('Lean Six Sigma Black Belt', 49),
#  ('LIVING THE LAWS OF LEADERSHIP', 49),
#  ('AI ADVANCE HUMANOID (YANSHEE - RASPBERRY PI) SERIES', 49),
#  ('ROBOT DESIGN, BUILD & PROGRAM - INTERMEDIATE SERIES 1', 49),
#  ('ROBOT DESIGN, BUILD & PROGRAM - FOUNDATIONAL SERIES 3', 49),
#  ('MASTER OF SCIENCE (TECHNOLOGY MANAGEMENT)', 49),
#  ('SGUS COMMUNITY AND PARTNERSHIPS SPECIALIST', 49),
#  ('Customer Referral Programs & Influencer Marketing', 48),
#  ('NICF - MTA: SOFTWARE DEVELOPMENT FUNDAMENTALS (SF)', 48),
#  ('POST-COVID SERVICE EXCELLENCE', 48),
#  ('DIGITAL BUSINESS OPERATIONS SPECIALIST - CAPSTONE PROJECT 5', 48),
#  ('DIGITAL BUSINESS OPERATIONS SPECIALIST - CAPSTONE PROJECT 1', 48),
#  ('DESKTOP SUPPORT ENGINEER - SUMMATIVE CAPSTONE PROJECT', 48),
#  ('Amazon Setup and Management Part-2: Global (1)', 48),
#  ('DIGITAL BUSINESS OPERATIONS SPECIALIST - CAPSTONE PROJECT 4', 48),
#  ('UNDERSTAND DIGITAL TRANSFORMATION', 48),
#  ('AGILESHIFT: ENTERPRISE AGILITY AND TRANSFORMATION', 48),
#  ('Amazon Setup and Management Part-1: Singapore', 48),
#  ('DIGITAL BUSINESS OPERATIONS SPECIALIST - CAPSTONE PROJECT 3', 48),
#  ('Bachelor of Business Administration', 48),
#  ('ADOBE CREATIVE SUITE (PHOTOSHOP, ILLUSTRATOR, INDESIGN, XD)', 48),
#  ('DIGITAL BUSINESS OPERATIONS SPECIALIST - CAPSTONE PROJECT 2', 48),
#  ('FUNDAMENTALS OF THE PERSONAL DATA PROTECTION ACT(SYNCHRONOUS E-LEARNING)',
#   47),
#  ('CERTIFIED AGILE PROCESS OWNER (CAPO)-P200924YRG', 47),
#  ('NICF - IT Fundamentals Part 2 (SF)', 47),
#  ('CPLESM THE FUNDAMENTALS OF EVENTS (SYNCHRONOUS E-LEARNING)', 47),
#  ('MODULE 12 - FINAL MODULE', 46),
#  ('MODULE 5 - SECURITY STRATEGIES', 46),
#  ('SUPERVISE WORKPLACE SAFETY AND HEALTH IN PROCESS PLANT', 46),
#  ('Advanced Certificate in Digital Health', 46),
#  ('MODULE 8 - ETHICAL HACKING', 46),
#  ('MODULE 11 - LABS AND SIMULATIONS', 46),
#  ('MODULE 9 - PROJECTS AND SIMULATIONS', 46),
#  ('MODULE 2 - NETWORKING', 46),
#  ('MODULE 10 - CYBER-DEFENSE', 46),
#  ('MODULE 6 - LABS AND SIMULATIONS', 46),
#  ('MODULE 3 - LABS MODULE', 46),
#  ('MODULE 7 - FORENSICS', 46),
#  ('MODULE 4 - THREATS, ATTACKS, TACTICS', 46),
#  ('NICF - RPA DEVELOPER FOUNDATION TRAINING (SF) (SYNCHRONOUS E-LEARNING)',
#   46),
#  ('AI HUMANOID (TRANSFORMER - AUDRINO) SERIES', 46),
#  ('Amazon Setup and Management Part-3: Global (2)', 45),
#  ('Data Analytics - Introduction', 45),
#  ('Advanced Diploma in Healthcare Management and Digital Health', 45),
#  ('AI ROBOTIC ASSISTANT (ALPHA MINI) SERIES', 45),
#  ('Data Analytics - Business Intelligence & Data Dashboards (Visualisation)',
#   45),
#  ('MODULE 1 - INTRODUCTION AND OVERVIEW OF THE CYBERSECURITY LANDSCAPE AND INDUSTRY',
#   45),
#  ('ROBOT DESIGN, BUILD & PROGRAM - INTERMEDIATE SERIES 2', 45),
#  ('HOW TO PITCH LIKE A PRO (SYNCHRONOUS E-LEARNING)', 45),
#  ('Data Analytics - Optimizing Marketing Campaigns (Google Analytics + Business Facebook)',
#   44),
#  ('NICF - Fundamentals of Blockchain for Business Professionals (SF)', 44),
#  ('SGUS ASSOCIATE UI/UX DESIGNER', 44),
#  ('ASSOCIATE AI / ROBOTICS ENGINEER - PROJECT: SMART FACTORY COMPETITION', 44),
#  ('An Introduction to Safe Dance Practice in MOE Schools', 44),
#  ('ASSOCIATE AI / ROBOTICS ENGINEER - PROJECT: SMART FACTORY MODEL BUILD UP',
#   44),
#  ('SGUnited Skills Programme in Digital Marketing (Synchronous & Asynchronous e-learning)',
#   44),
#  ('WORKSHOP FOR CEO / TOP MANAGEMENT (BIZSAFE LEVEL 1)', 44),
#  ('DIGITAL BUSINESS OPERATIONS SPECIALIST-CAPSTONE PROJECT 6', 44),
#  ('Certified Lean Six Sigma Green Belt', 43),
#  ('CONSTRUCTION SAFETY COURSE FOR PROJECT MANAGER', 43),
#  ('CREATING MOBILE VIDEO', 43),
#  ('MASTER OF SCIENCE (SYSTEMS & PROJECT MANAGEMENT)', 43),
#  ('EXECUTIVE REPORTING USING DYNAMIC AND INTERACTIVE EXCEL DASHBOARDS', 42),
#  ('BLOCKCHAIN FOR CROSS BORDER PAYMENT-P210913KUU', 42),
#  ('ENGINEERING (BIOENGINEERING)', 42),
#  ('MASTER OF SCIENCE (APPLIED GERONTOLOGY)', 42),
#  ('NICF - CYBERSECURITY AWARENESS PROGRAMME (SF). (SYNCHRONOUS E-LEARNING)',
#   42),
#  ('Professional Certificate in Community Care', 42),
#  ('SGUS ASSOCIATE AI / ROBOTICS ENGINEER', 41),
#  ('SERVICE RECOVERY TRAINING', 41),
#  ('SCIENCE (MATHEMATICS & ECONOMICS)', 41),
#  ('LEADING BUSINESS CONTINUITY MANAGEMENT-P210331ZNL', 41),
#  ('Lead Charger Series: CLIMB Digital Branding Module', 41),
#  ('ASSOCIATE AI / ROBOTICS ENGINEER - PROJECT: SMART AI CAR', 41),
#  ('POSTGRADUATE DIPLOMA IN EDUCATION (SPECIALISATION IN TEACHING AT SECONDARY SCHOOL LEVEL)',
#   40),
#  ('MANAGING CHANGE FOR HOSPITALITY', 40),
#  ('NICF - FUNDAMENTALS OF BLOCKCHAIN FOR BUSINESS PROFESSIONALS (SF)', 40),
#  ('Business Innovation: Building Renewed Business Relevance in Uncertain Times',
#   40),
#  ('NICF - IDENTITY WITH WINDOWS SERVER (SF) (SYNCHRONOUS E-LEARNING)', 40),
#  ('Business Finance', 40),
#  ('Doctor of Philosophy', 40),
#  ('MICROSOFT AZURE CLOUD FUNDAMENTALS', 40),
#  ('Diploma in Network Defence and Forensic Countermeasures', 39),
#  ('NICF - MICROSOFT AZURE ADMINISTRATOR (SF)', 39),
#  ('SGUS DESKTOP SUPPORT ENGINEER', 39),
#  ('BE A SERVICE DESIGN THINKER POWERED BY ESSEC-P200604YEP', 39),
#  ('SHIPYARD SUPERVISORS SAFETY COURSE', 38),
#  ('Art Therapy for Preventing Dementia', 38),
#  ('MAGIC OF CLOSING DEALS AND CREATING A GOOD IMPRESSION', 37),
#  ('CORE SPRING TRAINING', 37),
#  ('JAVA DEVELOPER - CAPSTONE PROJECT 4', 37),
#  ('SKILLSFUTURE FOR DIGITAL WORKPLACE IN HEALTHCARE', 37),
#  ('JAVA DEVELOPER - CAPSTONE PROJECT 3', 37),
#  ('JAVA DEVELOPER - CAPSTONE PROJECT 5', 37),
#  ('ORACLE DATABASE 12C: SQL AND PL/SQL FUNDAMENTALS', 37),
#  ('JAVA DEVELOPER - CAPSTONE PROJECT 2', 37),
#  ('Visual Communication Using Adobe Photoshop', 37),
#  ('USING THE FORSCORE APP TO EDIT AND MANAGE DIGITAL MUSIC SCORES IN REHEARSAL AND PERFORMANCE',
#   37),
#  ('DIGITAL BUSINESS OPERATIONS SPECIALIST - SUMMATIVE CAPSTONE PROJECT', 37),
#  ('SGUS DIGITAL BUSINESS OPERATIONS SPECIALIST', 37),
#  ('Fundamentals of Creative Sketching', 37),
#  ('5 STRATEGIES TO WIN WITH PEOPLE.', 37),
#  ('MASTERING THE FUNDAMENTALS OF SIBELIUS', 37),
#  ('DEVELOPING APPLICATIONS FOR THE JAVA EE 7 PLATFORM', 37),
#  ('NICF - JAVA SE: PROGRAMMING II (SF)', 37),
#  ('DIGITAL BUSINESS OPERATIONS SPECIALIST', 37),
#  ('STRENGTHENING YOUR WELLNESS AND RESILIENCE', 36),
#  ('SUPERVISE MARINE WORK FOR WSH', 36),
#  ('JAVA DEVELOPER - CAPSTONE PROJECT 1', 36),
#  ('MASTER OF SCIENCE (MECHANICAL ENGINEERING)', 36),
#  ('SGUS JAVA DEVELOPER', 35),
#  ('LEADING WITH AN EXPERIMENTAL MINDSET-P200811OTL', 35),
#  ('Standard First Aid with CPR(HO)+AED Refresher', 35),
#  ('ENGINEERING (COMPUTER ENGINEERING)', 35),
#  ('Data Analysis and Analytics - Practical Application (Synchronous e-Learning)',
#   35),
#  ('JAVA DEVELOPER - SUMMATIVE CAPSTONE PROJECT', 34),
#  ('Diploma in Design Communication', 34),
#  ('NICF - BLOCKCHAIN SOLUTION ARCHITECTURE TRAINING (SF) (SYNCHRONOUS E-LEARNING)',
#   34),
#  ('SGUS Programme for Healthcare Assistants', 33),
#  ('PROJECT MANAGEMENT FOR ALL (NTUC HEALTH)', 33),
#  ('Safe Riding on Pedal and Power-Assisted Bicycle (PAB)', 32),
#  ('Supervise Construction Work for WSH', 32),
#  ('NICF - INSTALLING AND CONFIGURING WINDOWS 10 (SF)', 31),
#  ('Introduction to Japanese Pastel Nagomi Art', 31),
#  ('DEVELOPING AN EXPERIMENTAL MINDSET WITHIN TEAMS-P200811ABC', 31),
#  ('CPR (HANDS-ONLY) + AED Provider', 31),
#  ('ASSOCIATE AI / ROBOTICS ENGINEER', 31),
#  ('NICF - MICROSOFT AZURE FUNDAMENTALS (SF)', 31),
#  ('APPLY WORKPLACE SAFETY AND HEALTH IN SHIPYARD(GENERAL TRADE)', 30),
#  ('JAVA DEVELOPER-CAPSTONE PROJECT 6', 30),
#  ('JAVA DEVELOPER', 30),
#  ('Master of Arts', 30),
#  ('HIGH-VALUE INNOVATION THROUGH FUSION: BEHIND-THE-SCENES STORIES AND CREATIVITY PROCESS',
#   30),
#  ('Master of IT in Business Programme', 30),
#  ('Managing Change for Hospitality (Synchronous e-learning)', 30),
#  ('THE SHIFTING ROLES OF LEADERS (SYNCHRONOUS E-LEARNING)', 29),
#  ('Transforming Enterprises Module 3: Manage', 29),
#  ('MASTER OF ARTS (TRANSLATION & INTERPRETATION)', 29),
#  ('Bachelor of Engineering (Mechanical Engineering)', 29),
#  ('POSTGRADUATE DIPLOMA IN EDUCATION (SPECIALISATION IN TEACHING AT PRIMARY SCHOOL LEVEL)',
#   29),
#  ('Innovation Culture Catalyst (ICC) and Mindset: The Secrets that Drive People and Innovation Programmes',
#   29),
#  ('Marketing Management', 29),
#  ('CYBER SECURITY PROTECTION CERTIFICATE (CSPC)-P190714SZU', 29),
#  ('Business and Financial Analytics', 29),
#  ('Psychology of Physical Activity', 29),
#  ('ACCELERATING TEAMWORK.', 29),
#  ('ARTIFICIAL INTELLIGENCE', 29),
#  ('Business Liability an Ethics in AI Usage', 28),
#  ('DATA ANALYSIS USING EXCEL PIVOTTABLE', 28),
#  ('STANDARD FIRST AID WITH CPR(HO)+AED', 28),
#  ('DEVELOP A RISK MANAGEMENT IMPLEMENTATION PLAN. (SYNCHRONOUS E-LEARNING)',
#   28),
#  ('TAKE CENTRESTAGE AND COMMAND AN AUDIENCE (Synchronous e-learning)', 28),
#  ('ISO 45001:2018 INTERNAL AUDITOR TRAINING', 28),
#  ('FUNDAMENTALS WEB DESIGN AND DEVELOPMENT USING WORDPRESS CMS', 28),
#  ('Art Therapy for Self Care', 27),
#  ('COMMUNITY MANAGEMENT', 27),
#  ('Master of Technology (Enterprise Business Analytics)', 27),
#  ('BASIC TRAFFIC MANAGEMENT COURSE', 27),
#  ('THE FUTURE OF EVENTS IN A POST-COVID WORLD: HOW TO MAKE SURE YOU ARE READY TO RIDE THE WAVE',
#   27),
#  ('BLOCKCHAIN FOR CORPORATE COMPLIANCE-P210917CNO', 27),
#  ('Business Analytics', 27),
#  ('FINE ARTS IN PHOTOGRAPHY & DIGITAL IMAGING', 27),
#  ('DIGITAL AND ME', 27),
#  ('Applications and Reasons for Security', 26),
#  ('Physical Activity, Nutrition & Health', 26),
#  ('Physical Activity and Health', 26),
#  ('Exercise Physiology', 26),
#  ('STARTING MY POWER-ASSISTED BICYCLE (PAB) JOURNEY', 25),
#  ('Innovating through Design Thinking: Refresher for Practitioners (Synchronous e-learning)',
#   25),
#  ('MASTER OF SCIENCE (MANUFACTURING SYSTEMS & ENGINEERING)', 25),
#  ('Graphic Design & Illustration Using Adobe Illustrator', 25),
#  ('SGUS DIGITAL CUSTOMER RELATIONS AMBASSADOR', 25),
#  ('ASSOCIATE UI/UX DESIGNER', 25),
#  ('SGUS NETWORK ENGINEER', 25),
#  ('Transforming Enterprises Module 2: Negotiate', 25),
#  ('Transforming Enterprises Module 1: Experience', 25),
#  ('FUNDAMENTALS OF THE PERSONAL DATA PROTECTION ACT (2020)', 25),
#  ('Lean Six Sigma Green Belt Certification', 25),
#  ('NICF - RPA Developer Foundation Training (SF)', 24),
#  ('NETWORK ENGINEER - SUMMATIVE CAPSTONE PROJECT', 24),
#  ('MICROSOFT EXCEL 2016: INTERMEDIATE (SYNCHRONOUS E-LEARNING)', 24),
#  ('MASTER OF SCIENCE (POWER ENGINEERING)', 24),
#  ('Transforming Enterprises Module 4: Present', 24),
#  ('CCNA PART-2', 24),
#  ('NETWORK ENGINEER - CAPSTONE PROJECT 1', 24),
#  ('1-DAY GEARING UP FOR A DIGITAL WORKPLACE IN PSA', 24),
#  ('SGUS APPLIED VR AND GAME SPECIALIST', 24),
#  ('CERTIFIED NETWORK DEFENDER (CND)', 24),
#  ('NETWORK ENGINEER - CAPSTONE PROJECT 4', 24),
#  ('NICF - FORTINET FORTIGATE NETWORK SECURITY PROFESSIONAL (NSE 4) (SF)', 24),
#  ('CCNA PART-1', 24),
#  ('DESKTOP SUPPORT ENGINEER', 24),
#  ('VMWARE NSX-T DATA CENTER: INSTALL, CONFIGURE, MANAGE', 24),
#  ('NETWORK ENGINEER - CAPSTONE PROJECT 2', 24),
#  ('NICF - RPA DESIGN & DEVELOPMENT (SF).', 24),
#  ('NETWORK ENGINEER - CAPSTONE PROJECT 5', 24),
#  ('NETWORK ENGINEER - CAPSTONE PROJECT 6', 24),
#  ('NETWORK ENGINEER - CAPSTONE PROJECT 3', 24),
#  ('ITIL 4 FOUNDATION', 23),
#  ('MASTER OF ENGINEERING', 23),
#  ('STANDARD FIRST AID WITH CPR(HO)+AED REFRESHER', 23),
#  ("Children's Art & Craft for Teachers & Parents", 23),
#  ('Hands-on Practical Applications of Blockchain (Synchronous e-learning)',
#   23),
#  ('NICF - PROGRAMMING IN HTML5 WITH JAVASCRIPT AND CSS3 (SF)', 23),
#  ('APPLIED VR & GAME SPECIALIST - CAPSTONE PROJECT 2', 23),
#  ('Diploma in Audio Production', 23),
#  ('Fundamentals of Project Management', 23),
#  ('FinTech: The Future of Money, Markets and Marketplaces', 23),
#  ('WORKSHOP FOR CEO/TOP MANAGEMENT - E LEARNING', 23),
#  ('STRATEGY DEVELOPMENT USING BMC-P210107CLR', 23),
#  ('COMMUNITY AND PARTNERSHIPS SPECIALIST', 22),
#  ('Develop a Workplace Safety and Health Management System Implementation Plan',
#   22),
#  ('NICF - MANAGING PROJECTS WITH MICROSOFT PROJECT (SF)', 22),
#  ('MASTER OF SCIENCE (CIVIL ENGINEERING)', 22),
#  ('Certificate in Teaching Drama and Speech (Advanced)', 22),
#  ('AUTODESK AUTOCAD ESSENTIALS', 22),
#  ('Bridging Course - Physics', 22),
#  ('Develop a Risk Management Implementation Plan.', 22),
#  ('Management of Project Plan, Schedule and Resources', 22),
#  ('Master of Science (Industrial and Systems Engineering)', 22),
#  ('FULL ACCESS TO ALL DUPONT RICH GENERIC E-LEARNING SERIES (VALID FOR 1-YEAR)',
#   21),
#  ('CPLESM THE FUNDAMENTALS OF EVENTS (Synchronous e-learning)', 21),
#  ('HFI UX 1 - USABILITY ENGINEERING COURSE REVISION', 21),
#  ('Transforming Enterprises Module 5: Create', 21),
#  ('THE 360 DEGREE LEADER.', 21),
#  ('FUNDAMENTALS OF THE PERSONAL DATA PROTECTION ACT (2020) (SYNCHRONOUS ELEARNING)',
#   21),
#  ('COMPUTER MAINTENANCE − BASIC DIAGNOSTIC & REPAIR', 21),
#  ('Art Teaching for Special Needs - Watercolour Painting', 21),
#  ('NICF - RPA Developer Foundation Training (SF).', 20),
#  ('SUPERVISE MANUFACTURING WORK FOR WSH', 20),
#  ('SCIENCE (ENVIRONMENTAL EARTH SYSTEMS SCIENCE)', 20),
#  ('STRENGTHENING YOUR WELLNESS & RESILIENCE (SYNCHRONOUS E-LEARNING)', 20),
#  ('Autodesk AutoCAD Essentials', 20),
#  ('Techniques in Watercolour', 20),
#  ('WORKING WITH SOCIAL INFLUENCERS', 20),
#  ('FACILITATING AND CONDUCTING VIRTUAL CLASSES ONLINE (SYNCHRONOUS E-LEARNING)',
#   20),
#  ('MANAGING CHANGE FOR HOSPITALITY (SYNCHRONOUS E-LEARNING)', 19),
#  ('Traditional Chinese Medicine for Older Adults', 19),
#  ('MASTER OF SCIENCE (FINANCIAL ENGINEERING)', 19),
#  ('DIGITAL LEADERSHIP', 19),
#  ('Master of Science (Project Management)', 19),
#  ('NICF - IDENTITY WITH WINDOWS SERVER (SF)', 19),
#  ('Master of Computing', 19),
#  ('ENGINEERING SCIENCE (COMPUTER SCIENCE)', 19),
#  ('BASIC CARDIAC LIFE SUPPORT COURSE + AUTOMATED EXTERNAL DEFIBRILLATION', 19),
#  ('KNOW YOUR CUSTOMERS THROUGH HUMAN CENTERED APPROACH', 19),
#  ('DEVELOPING AND MANAGING EFFECTIVE HR POLICIES AND PROCEDURES', 19),
#  ('Master of Science (Civil Engineering)', 19),
#  ('Master of Science (Industry 4.0)', 18),
#  ('THE SHIFTING ROLES OF LEADERS', 18),
#  ('DIGITAL CITIZEN TABLET FUNDAMENTALS', 18),
#  ('Diploma in Broadcast Media', 18),
#  ('CPLESM THE FUNDAMENTALS OF EVENTS', 18),
#  ("STAKEHOLDERS' RESPONSIBILITY TOWARDS WSH", 18),
#  ('MASTER OF SCIENCE (ASIAN STUDIES)', 18),
#  ('EFFECTIVE PERFORMANCE MANAGEMENT AND APPRAISALS', 17),
#  ('SGUnited Skills Programme in Business Analytics and Automation Tools (Synchronous & Asynchronous e-learning)',
#   17),
#  ('COMMUNITY AND PARTNERSHIPS SPECIALIST - CAPSTONE PROJECT 1', 17),
#  ('Certificate in Infographics', 17),
#  ('BRIDGING COURSE - PHYSICS', 17),
#  ('Health Coaching for Older Adults', 17),
#  ('Western Painting (Acrylic/ Oil) (Level 1)', 17),
#  ('EFFECTIVE PRESENTATION SKILLS', 17),
#  ('ORGANISING WEBINAR AND VIRTUAL EVENTS', 17),
#  ('Lean Six Sigma Gold Belt', 16),
#  ('THE MACHINE LEARNING PIPELINE ON AWS-P200623GUW', 16),
#  ('Data Analysis using Excel PivotTable', 16),
#  ('TDVL REFRESHER (ACTIVE DRIVER) COURSE', 16),
#  ('STANDARD FIRST AID WITH CPR (HO) + AED REFRESHER', 16),
#  ('ACCELERATING TEAMWORK', 16),
#  ('Advanced Diploma in Growing and Transforming Enterprises (2 Modules)', 16),
#  ('Safety Instruction Course for Shiprepair Managers', 16),
#  ('Quantitative Methods for Logistics Analysis', 16),
#  ('COURAGEOUS CONVERSATION', 16),
#  ('Supply Chain Engineering', 15),
#  ('Design Thinking and Innovation', 15),
#  ('Corporate Resource Planning', 15),
#  ('Procurement & Supplier Development', 15),
#  ('SOCIAL SCIENCES (SOCIOLOGY)', 15),
#  ('Re-Imagining Tourism through the Lenses of Augmented Reality', 15),
#  ('Linear and Nonlinear Programming', 15),
#  ('Graduate Diploma in Systems Analysis', 15),
#  ('Build Resilience and Develop Skills to Lead Change', 15),
#  ('Holistic Value Chain Management in Food and Beverage (F&B)', 15),
#  ('MASTER OF SCIENCE (ENVIRONMENTAL ENGINEERING)', 15),
#  ('Advanced Certificate in Transforming Enterprises', 15),
#  ('Digital Marketing (SMU)', 15),
#  ('Diploma in Fine Arts', 15),
#  ('HOTEL JOB REDESIGN WORKSHOP & CONSULTATION', 15),
#  ('Nagomi Art with Mixed Medium', 15),
#  ('Management of Logistics Functions', 15),
#  ('MASTER OF SCIENCE (BIOMEDICAL ENGINEERING)', 15),
#  ('Advanced Certificate in Cyber War-Gaming Module 1: Vulnerability Assessment and Penetration Testing',
#   14),
#  ('INTRODUCTION TO MICROSOFT EXCEL VBA', 14),
#  ('BASIC FM ENABLER COURSE (LEVEL 1)', 14),
#  ('DIGITAL HR BUSINESS PARTNER - CAPSTONE PROJECT 1', 14),
#  ('Bachelor of Engineering (Electrical Engineering)', 14),
#  ('Certificate in Watercolour Painting (Advanced)', 14),
#  ('THE 5 LEVELS OF LEADERSHIP', 14),
#  ('RIDE OVER CHANGES THROUGH A GROWTH MINDSET', 14),
#  ('Critical Thinking for Innovation in Enterprises (Synchronous e-Learning)',
#   13),
#  ('Perspectives on Ageing', 13),
#  ('SUPERVISE CONSTRUCTION WORK FOR WSH (SYNCHRONOUS E-LEARNING)', 13),
#  ('INTERNATIONAL TRADE (IMPORT/ EXPORT)', 13),
#  ('DEVELOP A RISK MANAGEMENT IMPLEMENTATION PLAN.', 13),
#  ('SGUnited Skills Programme in UX Design and Product Management (Synchronous & Asynchronous e-learning)',
#   13),
#  ('Safe Management Officer Course For Construction', 13),
#  ('MASTER OF SCIENCE (SMART PRODUCT DESIGN)', 13),
#  ('SMU Executive Certificate in EdTech for Educators', 12),
#  ('NICF - RPA PRIMER (SF)', 12),
#  ('MANAGING WORK-AT-HEIGHTS COURSE', 12),
#  ('NICF - Project Management Fundamentals (SF)', 12),
#  ('DATA ANALYSIS FUNDAMENTALS USING MICROSOFT EXCEL', 12),
#  ('INCREASING PRODUCTIVITY FOR TEAM LEADERS', 12),
#  ('Digital Transformation Through Process Automation - RPA', 12),
#  ('NTU-FTA Series - Artificial Intelligence and Machine Learning (Synchronous e-Learning)',
#   12),
#  ('Master of Science (Electrical Engineering)', 12),
#  ('SGUnited Skills Programme in Cyber Security Specialist', 12),
#  ('APPLY FUNDAMENTALS OF LOGIC PRO X IN MUSIC PRODUCTION (Synchronous e-learning)',
#   12),
#  ('Ground Leader Milestone Training Programme', 12),
#  ('Master of Science (Supply Chain Management)', 12),
#  ('FINE ARTS IN INTERACTIVE MEDIA', 12),
#  ('Embrace the Era of Blockchain (Synchronous E-learning)', 12),
#  ('DIGITAL READINESS', 12),
#  ('OFFICE 365 END USER TRAINING(SYNCHRONOUS E-LEARNING)', 11),
#  ('RISK MANAGEMENT COURSE (BIZSAFE LEVEL 2) - WKDAY (ENGLISH)', 11),
#  ('Data Analysis and Analytics - Practical Application (Synchronous e-learning)',
#   11),
#  ('UNDERSTANDING & APPLYING WICA & WSHA', 11),
#  ('SELF-PROTECTION MEASURES IN CHALLENGING SITUATIONS', 11),
#  ('JOB ANALYSIS AND REDESIGN MASTERCLASS', 11),
#  ('MASTER OF ARTS (CONTEMPORARY CHINA)', 11),
#  ('Bachelor of Engineering (Civil Engineering)', 11),
#  ('Bachelor of Engineering (Environmental Engineering)', 11),
#  ('HOTEL JOB REDESIGN WORKSHOP & CONSULTATION (SYNCHRONOUS E-LEARNING)', 11),
#  ('FUNDAMENTALS OF BUILDING SERVICES AND SAFETY', 11),
#  ('HOW TO PITCH LIKE A PRO', 11),
#  ('COMMUNICATING WITH EXECUTIVE PRESENCE', 11),
#  ('MICROSOFT TEAM COLLABORATION AND COMMUNICATION', 11),
#  ('Master of Science (Management of Technology)', 11),
#  ('Advanced Diploma in Growing and Transforming Enterprises (3 Modules)', 11),
#  ('DEVELOP A WORKPLACE SAFETY AND HEALTH MANAGEMENT SYSTEM IMPLEMENTATION PLAN',
#   11),
#  ('ENTERPRISE RISK MANAGEMENT IN PRACTICE (A FOUNDATION COURSE) - P210915UKL',
#   10),
#  ('Materials Science and Engineering', 10),
#  ('Nanyang Enterprise Risk Management Programme - Module 1 (ERM Strategic Business Leadership)',
#   10),
#  ('Processes for Particulate Materials and Bulk Materials', 10),
#  ('HFI USABILITY AND PET ORIENTATION PROGRAM', 10),
#  ('NICF - LINUX COMMAND LINE AND SHELL SCRIPTING (SF)', 10),
#  ('PCFBB2: Accounting & Legal Considerations in the F&B Industry - Building a Sustainable Business',
#   10),
#  ('Master of Education (Music)', 10),
#  ('Vacuum Processes', 10),
#  ('MASTER OF SCIENCE (COMMUNICATIONS ENGINEERING)', 10),
#  ('Innovation Culture Catalyst (ICC): The Game Changer \\n(Synchronous e-learning)',
#   10),
#  ('Construction Management', 10),
#  ('PCFBB1: Introduction to the F&B Industry - Opportunities and Growth Areas',
#   10),
#  ('MANAGING PEOPLE IN DIFFICULT SITUATIONS', 10),
#  ('Graduate Diploma in Human Resource Management', 10),
#  ('Supply Chain Analysis and Design', 10),
#  ('Microsoft Excel 2016: Advanced', 10),
#  ('ISO 9001:2015 INTERNAL AUDITOR TRAINING', 10),
#  ('Solution Processes', 10),
#  ('Certificate in Graphic Communication (Digital Graphics and Principles)', 9),
#  ('APPLY WORKPLACE SAFETY AND HEALTH IN SHIPYARD (GENERAL TRADE) (ENGLISH)',
#   9),
#  ('Supervise Tunnelling Work for WSH', 9),
#  ('PROCESS AUTOMATION (SYNCHRONOUS E-LEARNING)', 9),
#  ('POST-COVID HOUSEKEEPING EXCELLENCE', 9),
#  ('WORKFORCE REDESIGN PROGRAMME', 9),
#  ('Principles and Adaptation', 9),
#  ('Bachelor of Technology (Mechanical Engineering)', 9),
#  ('Lean Six Sigma Black Belt Certification', 9),
#  ('SAFE & DEFENSIVE DRIVING COURSE', 9),
#  ('MASTER OF SCIENCE (COMPUTER CONTROL & AUTOMATION)', 9),
#  ('Digital Marketing (SMU) (Synchronous e-learning)', 9),
#  ('NICF - Automating Administration with Windows PowerShell (SF)', 9),
#  ('Fundamentals of Electron Microscopy', 9),
#  ('Design Thinking and Innovation (Synchronous e-learning)', 9),
#  ('Advanced Characterization using TEM Techniques', 9),
#  ('Master of Science (Safety, Health and Environmental Technology)', 9),
#  ('Bachelor of Computing (Computer Science)', 9),
#  ('AIR-CONDITIONING − BASIC MAINTENANCE FOR HOME SPLIT UNIT', 9),
#  ('SOCIAL SCIENCES (ECONOMICS)', 9),
#  ('Professional Diploma in Digital Marketing and Campaign Strategy', 9),
#  ('Diploma in Technical and Production Management', 8),
#  ('APPLY WORKPLACE SAFETY AND HEALTH IN SHIPYARD (GENERAL TRADE)', 8),
#  ('Bachelor of Engineering (Biomedical Engineering)', 8),
#  ('NICF - BLOCKCHAIN SOLUTION ARCHITECTURE TRAINING (SF)', 8),
#  ('MICROSOFT EXCEL 2016: ADVANCED', 8),
#  ('STRUCTURED AND BEHAVIOURAL-BASED INTERVIEW SKILLS', 8),
#  ('MASTER OF SCIENCE (DIGITAL MEDIA TECHNOLOGY)', 8),
#  ('MICROSOFT EXCEL ESSENTIAL', 8),
#  ('Diploma in Dance', 8),
#  ('Master of Science (Financial Engineering)', 8),
#  ('Develop a Risk Management Implementation Plan', 8),
#  ('MANAGING EVENTS PHYSICAL SECURITY RISKS (SYNCHRONOUS E-LEARNING)', 8),
#  ('MASTER OF SCIENCE (ELECTRONICS)', 8),
#  ('STANDARD FIRST AID COURSE WITH CPR(HO) + AED', 8),
#  ('BUS DRIVER BASIC DRIVING SAFETY COURSE', 7),
#  ('Construction Technology', 7),
#  ('WORKFLOW AUTOMATION (SYNCHRONOUS E-LEARNING)', 7),
#  ('Social Psychology', 7),
#  ('DIGITAL READINESS (Synchronous e-learning)', 7),
#  ('CONFINED SPACE SAFETY ASSESSOR COURSE', 7),
#  ('Professional Certificate in Counseling', 7),
#  ('Diploma in Business Administration (Supply Chain Management)', 7),
#  ('Master of Science (Pharmaceutical Science and Technology)', 7),
#  ('CAPSTONE PROJECT 1: DESIGNING A WEBSITE/APP USING UCD METHODOLOGY PART 1',
#   7),
#  ('Advanced Certificate in Corporate Governance for NextGen Business Leaders Module 1: Rethinking Corporate Governance for the New World',
#   7),
#  ('MASTER OF SCIENCE (ARTIFICIAL INTELLIGENCE)', 7),
#  ('Bachelor of Science (Project and Facilities Management)', 7),
#  ('Innovation Culture Catalyst (ICC): The Game Changer', 7),
#  ('SAFE MANAGEMENT MEASURES AND PROFESSIONAL ENGAGEMENT WITH GUESTS', 7),
#  ('SMU-CERTIS Advanced Certificate in Innovation', 7),
#  ('ACHIEVE RESULTS WITH WINNING PRESENTATIONS', 7),
#  ('EMPLOYMENT ACT PROGRAMME', 7),
#  ('RISK MANAGEMENT COURSE (BIZSAFE LEVEL 2)', 7),
#  ('ASSOCIATE PROJECT MANAGER / SCRUM MASTER - CAPSTONE PROJECT 1', 7),
#  ('CPR(HANDS-ONLY)AED PROVIDER', 7),
#  ('CERTIFIED SCRUM PRODUCT OWNER (CSPO)', 7),
#  ('Advanced Certificate in Corporate Governance for NextGen Business Leaders Module 6: Auditing Digitalised Environments',
#   7),
#  ('WIREFRAMING USING ADOBE XD', 7),
#  ('BUILDING CONSTRUCTION SUPERVISORS SAFETY COURSE', 7),
#  ('MASTER OF SCIENCE (PRECISION ENGINEERING)', 7),
#  ('ENGINEERING SCIENCE (MECHANICAL ENGINEERING)', 7),
#  ('PERFORM METAL SCAFFOLD ERECTION', 7),
#  ('Develop a Positive Mindset to Workplace Changes (Synchronous e-Learning)',
#   6),
#  ('SERVICE RECOVERY TRAINING - CHINESE', 6),
#  ('Variation and Nonstoichiometry', 6),
#  ('ICAGILE AGILE TEAM FACILITATION', 6),
#  ('Operating Systems', 6),
#  ('Specialist Certificate in Civil Infrastructure', 6),
#  ('Diploma in Data Analytics', 6),
#  ('Master of Science (Mechanical Engineering)', 6),
#  ('APPLY WORKPLACE SAFETY AND HEALTH IN SHIPYARD(GENERAL TRADE) (ENGLISH)', 6),
#  ('NICF - Networking with Windows Server (PCP) (SF)', 6),
#  ('Reinforced Concrete Design', 6),
#  ('ENGINEERING SCIENCE (AEROSPACE ENGINEERING)', 6),
#  ('Develop a Postive Mindset to Workplace Changes (Synchronous e-Learning)',
#   6),
#  ('WSH COMMITTEE MEMBERS TRAINING COURSE 2-DAYS', 6),
#  ('Master of Science (Life Sciences)', 6),
#  ('Master of Science (Environmental Management)', 6),
#  ('Introduction to Electrical Circuits & Electronic Devices', 5),
#  ('TAXI DRIVER VOCATIONAL LICENCE COURSE', 5),
#  ('SECURITY OFFICER SELF PROTECTION', 5),
#  ('Master of Science (Geotechnical Engineering)', 5),
#  ('Diploma in Product Design', 5),
#  ('Bachelor of Engineering (Industrial and Systems Engineering)', 5),
#  ('CPR(Hands-Only)+AED PROVIDER', 5),
#  ('Certificate in Fashion Design', 5),
#  ('Master of Science (Finance)', 5),
#  ('SMU Advanced Certificate: Client Acquisition & Management (IBF Level 2)',
#   5),
#  ('ISO 45001 OCCUPATIONAL SAFETY & HEALTH MANAGEMENT SYSTEM AND ISO 45001 OCCUPATIONAL HEALTHY & SAFETY (OH&S) MANAGEMENT SYSTEMS IMPLEMENTER TRAINING',
#   5),
#  ('Financial Management', 5),
#  ('Graduate Diploma in Maritime Law and Arbitration', 5),
#  ('Anti-Money Laundering and its Ecosystem (Synchronous e-learning)', 5),
#  ('Master of Science (Chemical Engineering)', 5),
#  ('COMPTIA NETWORK', 5),
#  ('Master of Science (Systems Design and Management)', 5),
#  ('AI and Machine Learning in FinTech (Synchronous e-learning)', 5),
#  ('Computer Security (System Security)', 5),
#  ('Softbank Certificate - Robot Cleaning Operator Basic', 5),
#  ('SOCIAL SCIENCES (PUBLIC POLICY & GLOBAL AFFAIRS)', 5),
#  ('Object Oriented Design and Programming', 5),
#  ('MASTER OF SCIENCE (FINANCE)', 5),
#  ('BUY-IN', 4),
#  ('Master of Science (Business Analytics)', 4),
#  ('ENGINEERING SCIENCE (CHEMICAL & BIOMOLECULAR ENGINEERING)', 4),
#  ('Master in Public Administration', 4),
#  ('MASTER OF SCIENCE (SIGNAL PROCESSING)', 4),
#  ('Manufacturing Processes', 4),
#  ('HOW TO BEGIN YOUR YOUTUBE CONTENT CREATOR JOURNEY?', 4),
#  ('Microsoft Excel 2016: Intermediate', 4),
#  ('BASIC UNARMED COMBAT TRAINING', 4),
#  ('DIGITAL WORKPLACE: BUSINESS PROCESS AND WORKFLOW AUTOMATION - DESIGN, DEPLOY AND MANAGE (SYNCHRONOUS E-LEARNING)',
#   4),
#  ('OPERATIONALISING THE OUTCOME-BASED SECURITY CONTRACT', 4),
#  ('Master of Science (Marketing Analytics and Insights)', 4),
#  ('NICF - Networking with Windows Server (SF)', 4),
#  ('ENGINEERING SCIENCE (CIVIL ENGINEERING)', 4),
#  ('ENGINEERING SCIENCE (ELECTRICAL & ELECTRONIC ENGINEERING)', 4),
#  ('Advanced Certificate in Event Management and Entertainment: Creative Concepts and New Technology Levers (Synchronous e-learning)',
#   4),
#  ('DESIGN & DEVELOPMENT WITH RPA', 4),
#  ('WSQ PREPARING ONESELF TO ADAPT TO CHANGING ROLES IN WORKPLACE', 4),
#  ('Managing Work-at-Heights Course', 4),
#  ('Apply Workplace Safety and Health in Process Plant', 4),
#  ('INTRODUCTION TO CYBERSECURITY ACT', 4),
#  ('MASTER OF SCIENCE (INTERNATIONAL CONSTRUCTION MANAGEMENT)', 4),
#  ('Diploma in Dance with Distinction', 4),
#  ('Master of Technology (Software Engineering)', 4),
#  ('Bachelor of Technology (Industrial and Management Engineering)', 3),
#  ('Establish Lean Six Sigma Methodology', 3),
#  ('CPR (Hands-Only) + AED Provider', 3),
#  ('ISO 37001:2016 Anti-bribery Management System Awareness Training Course',
#   3),
#  ('COC IN RPA DEVELOPER FOUNDATION TRAINING', 3),
#  ('MANAGE WORKPLACE SAFETY AND HEALTH IN SHIPBUILDING AND SHIP REPAIR', 3),
#  ('Master of Science (Audiology)', 3),
#  ('HOME RENOVATION − PREPARATION & IDEAS', 3),
#  ('SAFE MANAGEMENT MEASURES PREPARING WORKPLACE FOR COVID-19', 3),
#  ('Shipyard Safety Assessors (Hot-Work Certification) Course', 3),
#  ('Digital Banks - Strategies & Target Operating Models \\n(synchronous e-learning)',
#   3),
#  ('Bachelor of Technology (Chemical Engineering)', 3),
#  ('DIGITAL WORKPLACE', 3),
#  ('Customer Service Experience Programme', 3),
#  ('WORKSHOP FOR CEO / TOP MANAGEMENT (bizSAFE LEVEL 1)', 3),
#  ('Master of Science (Food Science and Human Nutrition)', 3),
#  ('Data Visualisation and Dashboarding (Synchronous E-learning)', 3),
#  ('MICROSOFT POWEPOINT 2016: ADVANCED', 3),
#  ('WSH COMMITTEE MEMBERS TRAINING 1-DAY', 3),
#  ('OCCUPATIONAL FIRST AID', 3),
#  ('BASIC TRAFFIC CONTROL COURSE', 3),
#  ('DESIGN SPRINT', 3),
#  ('MASTER OF SCIENCE (EMBEDDED SYSTEMS)', 3),
#  ('1-DAY GEARING UP FOR A DIGITAL WORKPLACE IN PSA (Synchronous and Asynchronous e-learning)',
#   3),
#  ('Business Model Innovation (BMI) Programme', 3),
#  ('Specialist Certificate in Software Basics II', 2),
#  ('CPR(Hands-Only)AED Provider', 2),
#  ('WORK-AT-HEIGHT COURSE FOR SUPERVISORS', 2),
#  ('NICF - JAVA SE: PROGRAMMING I (SF) (SYNCHRONOUS E-LEARNING)', 2),
#  ('Power Systems and Conversion', 2),
#  ('Design Leadership & Design Thinking Facilitation - a Train-the-Trainer Programme (Synchronous e-learning)',
#   2),
#  ('MTA: WINDOWS OPERATING SYSTEM FUNDAMENTALS', 2),
#  ('Trade Finance Management', 2),
#  ('ENVIRONMENTAL CONTROL COORDINATOR (ECC) COURSE (SYNCHRONOUS E-LEARNING)',
#   2),
#  ('SOCIAL MEDIA LIVE STREAMING COURSE', 2),
#  ('ENGINEERING SCIENCE (ENVIRONMENTAL ENGINEERING)', 2),
#  ('SCIENCE (MATHEMATICAL SCIENCES AND ECONOMICS)', 2),
#  ('Preparatory Course in Business (RMIT)', 2),
#  ...]

# %%
len(community_sorted)
# Out:
# 1078

# %%
weights = sorted(G.edges(data=True), key=lambda x: x[2]['weight'], reverse=True)

count = 20
for item in weights:
    if item[0] != item[1] and count > 0:
        print(item)
        count -= 1
# Out:
# ('SAFE MANAGEMENT OFFICER COURSE FOR CONSTRUCTION', 'SAFE MANAGEMENT OFFICER TRAINING', {'weight': 13317})
# ('SAFE MANAGEMENT OFFICER COURSE FOR CONSTRUCTION', 'UNDERSTANDING & APPLYING WICA & WSHA', {'weight': 6562})
# ('SAFE MANAGEMENT OFFICER COURSE FOR CONSTRUCTION', 'MAINTENANCE SAFETY COURSE LOCK-OUT PROCEDURES', {'weight': 5018})
# ('SAFE MANAGEMENT MEASURES - PREPARING WORKPLACE FOR COVID-19', 'SAFE MANAGEMENT OFFICER COURSE FOR CONSTRUCTION', {'weight': 3878})
# ('CPR(HANDS-ONLY)+AED PROVIDER', 'OCCUPATIONAL FIRST AID COURSE', {'weight': 3596})
# ('CPR(HANDS-ONLY)+AED PROVIDER', 'SAFE MANAGEMENT OFFICER COURSE FOR CONSTRUCTION', {'weight': 2631})
# ('OCCUPATIONAL FIRST AID COURSE', 'SAFE MANAGEMENT OFFICER COURSE FOR CONSTRUCTION', {'weight': 2586})
# ('SAFE MANAGEMENT OFFICER TRAINING', 'UNDERSTANDING & APPLYING WICA & WSHA', {'weight': 2346})
# ('SAFE MANAGEMENT OFFICER TRAINING', 'MAINTENANCE SAFETY COURSE LOCK-OUT PROCEDURES', {'weight': 1794})
# ('BLOCKCHAIN FOR CROSS BORDER PAYMENT', 'BLOCKCHAIN FOR CORPORATE COMPLIANCE', {'weight': 1666})
# ('WORKSHOP FOR CEO/TOP MANAGEMENT - E Learning', 'Safe Management Officer Training', {'weight': 1560})
# ('ICAGILE - AGILE COACHING', 'ICAGILE - AGILE TEAM FACILITATION', {'weight': 1448})
# ('SAFE MANAGEMENT MEASURES - PREPARING WORKPLACE FOR COVID-19', 'SAFE MANAGEMENT OFFICER TRAINING', {'weight': 1380})
# ('SAFE MANAGEMENT OFFICER COURSE FOR CONSTRUCTION', 'WSH COMMITTEE MEMBERS TRAINING COURSE', {'weight': 1352})
# ('DATA ANALYSIS FUNDAMENTALS USING MICROSOFT EXCEL (IBF)', 'PROJECT MANAGEMENT FOR ALL', {'weight': 1326})
# ('PROJECT MANAGEMENT FOR ALL', 'ICAGILE - AGILE TEAM FACILITATION', {'weight': 1318})
# ('BUSINESS', 'ACCOUNTANCY', {'weight': 1269})
# ('DATA ANALYSIS FUNDAMENTALS USING MICROSOFT EXCEL (IBF)', 'BUSINESS ANALYTICS WITH QLIK SENSE', {'weight': 1206})
# ('BUILD RESILIENCE AND DEVELOP SKILLS TO LEAD CHANGE', 'IMPROVING MENTAL WELLBEING AND SELF-CARE FOR A HAPPIER YOU (SYNCHRONOUS AND ASYNCHRONOUS)', {'weight': 1159})
# ('BLOCKCHAIN FOR CROSS BORDER PAYMENT', 'PROJECT MANAGEMENT FOR ALL', {'weight': 1080})
